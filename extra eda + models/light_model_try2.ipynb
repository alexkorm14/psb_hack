# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
import optuna
from optuna.samplers import TPESampler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
# Загрузка данных
train = pd.read_excel('data/train.xlsx', index_col=0)
test = pd.read_excel('data/test.xlsx', index_col=0)

# Создание целевой переменной
train['Cancellation Status'] = train['Дата отмены'].apply(lambda x: 0 if pd.isna(x) else 1)

# Удаление столбцов, чтобы избежать утечки данных
train.drop(['Статус брони', 'Дата отмены'], axis=1, inplace=True)

# Объединение данных для консистентной предобработки
train_len = len(train)
data = pd.concat([train.drop('Cancellation Status', axis=1), test], axis=0)

# %%
# Функция для расширенного создания признаков
# Функция для расширенного создания признаков
def preprocess_data(df):
    # Конвертация дат в формат datetime
    df['Дата бронирования'] = pd.to_datetime(df['Дата бронирования'])
    df['Заезд'] = pd.to_datetime(df['Заезд'])
    df['Выезд'] = pd.to_datetime(df['Выезд'])
    
    # Создание новых признаков из дат
    df['booking_year'] = df['Дата бронирования'].dt.year
    df['booking_month'] = df['Дата бронирования'].dt.month
    df['booking_day'] = df['Дата бронирования'].dt.day
    df['booking_dayofweek'] = df['Дата бронирования'].dt.dayofweek
    df['booking_weekofyear'] = df['Дата бронирования'].dt.isocalendar().week
    df['booking_is_weekend'] = df['booking_dayofweek'].apply(lambda x: 1 if x >= 5 else 0)
    df['booking_hour'] = df['Дата бронирования'].dt.hour
    df['booking_minute'] = df['Дата бронирования'].dt.minute

    df['checkin_year'] = df['Заезд'].dt.year
    df['checkin_month'] = df['Заезд'].dt.month
    df['checkin_day'] = df['Заезд'].dt.day
    df['checkin_dayofweek'] = df['Заезд'].dt.dayofweek
    df['checkin_is_weekend'] = df['checkin_dayofweek'].apply(lambda x: 1 if x >= 5 else 0)

    df['checkout_year'] = df['Выезд'].dt.year
    df['checkout_month'] = df['Выезд'].dt.month
    df['checkout_day'] = df['Выезд'].dt.day
    df['checkout_dayofweek'] = df['Выезд'].dt.dayofweek
    df['checkout_is_weekend'] = df['checkout_dayofweek'].apply(lambda x: 1 if x >= 5 else 0)

    # Разница между датами
    df['booking_to_checkin_days'] = (df['Заезд'] - df['Дата бронирования']).dt.days
    df['checkin_to_checkout_days'] = (df['Выезд'] - df['Заезд']).dt.days
    df['booking_to_checkout_days'] = (df['Выезд'] - df['Дата бронирования']).dt.days

    # Создание признаков из 'Категория номера'
    df['Категория номера'] = df['Категория номера'].astype(str)
    df['room_category_length'] = df['Категория номера'].apply(len)
    df['room_category_words'] = df['Категория номера'].apply(lambda x: len(x.split()))
    df['room_category_unique_chars'] = df['Категория номера'].apply(lambda x: len(set(x)))
    df['room_category_digits'] = df['Категория номера'].apply(lambda x: sum(c.isdigit() for c in x))
    df['room_category_uppercase'] = df['Категория номера'].apply(lambda x: sum(c.isupper() for c in x))
    df['room_category_title_case'] = df['Категория номера'].apply(lambda x: sum(word.istitle() for word in x.split()))
    df['room_category_num'] = df['Категория номера'].str.extract(r'(\d+)').astype(float)  # Исправлено
    df['room_category_num'] = df['room_category_num'].fillna(df['room_category_num'].mean())

    # Дополнительные числовые признаки
    df['cost_per_night'] = df['Стоимость'] / df['Ночей']
    df['cost_per_room'] = df['Стоимость'] / df['Номеров']
    df['cost_per_guest'] = df['Стоимость'] / df['Гостей']
    df['rooms_per_guest'] = df['Номеров'] / df['Гостей']
    df['nights_per_guest'] = df['Ночей'] / df['Гостей']
    df['cost_per_night_per_room'] = df['Стоимость'] / (df['Ночей'] * df['Номеров'])
    df['cost_per_night_per_guest'] = df['Стоимость'] / (df['Ночей'] * df['Гостей'])
    df['prepayment_ratio'] = df['Внесена предоплата'] / df['Стоимость']
    df['remaining_payment'] = df['Стоимость'] - df['Внесена предоплата']
    df['remaining_payment_ratio'] = df['remaining_payment'] / df['Стоимость']

    # Флаги наличия предоплаты
    df['has_prepayment'] = df['Внесена предоплата'].apply(lambda x: 1 if x > 0 else 0)

    # Взаимодействия между признаками
    df['rooms_times_nights'] = df['Номеров'] * df['Ночей']
    df['guests_per_room'] = df['Гостей'] / df['Номеров']

    # Средняя стоимость на человека
    df['avg_cost_per_person'] = df['Стоимость'] / df['Гостей']

    # Дропаем исходные столбцы дат
    df.drop(['Дата бронирования', 'Заезд', 'Выезд', 'Категория номера'], axis=1, inplace=True)

    # Заполнение пропусков
    df['Внесена предоплата'] = df['Внесена предоплата'].fillna(0)
    df['room_category_num'] = df['room_category_num'].fillna(0)
    df['prepayment_ratio'] = df['prepayment_ratio'].fillna(0)
    df['remaining_payment_ratio'] = df['remaining_payment_ratio'].fillna(0)
    df['cost_per_night'] = df['cost_per_night'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['cost_per_room'] = df['cost_per_room'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['cost_per_guest'] = df['cost_per_guest'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['rooms_per_guest'] = df['rooms_per_guest'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['nights_per_guest'] = df['nights_per_guest'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['cost_per_night_per_room'] = df['cost_per_night_per_room'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['cost_per_night_per_guest'] = df['cost_per_night_per_guest'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['guests_per_room'] = df['guests_per_room'].replace([np.inf, -np.inf], np.nan).fillna(0)
    df['avg_cost_per_person'] = df['avg_cost_per_person'].replace([np.inf, -np.inf], np.nan).fillna(0)
    
    return df

# %%
data = preprocess_data(data)

# %%
# Удаление столбца '№ брони'
data = data.drop('№ брони', axis=1)

# Обработка категориальных признаков
categorical_cols = ['Способ оплаты', 'Источник', 'Гостиница']
data = pd.get_dummies(data, columns=categorical_cols)

# Очистка названий столбцов
data.columns = data.columns.str.replace(r'[^\w\s]', '', regex=True).str.replace(r'\s+', '_', regex=True)
data.columns = data.columns.astype(str)

# %%
# Разделение данных обратно на train и test
X = data.iloc[:train_len, :]
X_test = data.iloc[train_len:, :]
y = train['Cancellation Status']

# Стандартизация числовых признаков
numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns
scaler = StandardScaler()
X[numeric_cols] = scaler.fit_transform(X[numeric_cols])
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# Отбор признаков с помощью модели LightGBM
lgb_clf = lgb.LGBMClassifier(n_estimators=1000, random_state=42)
lgb_clf.fit(X, y)

# Используем важность признаков для отбора
importances = pd.Series(lgb_clf.feature_importances_, index=X.columns)
importances = importances.sort_values(ascending=False)
# Out:
# [LightGBM] [Info] Number of positive: 5192, number of negative: 20982
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004428 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3819
# [LightGBM] [Info] Number of data points in the train set: 26174, number of used features: 76
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.198365 -> initscore=-1.396546
# [LightGBM] [Info] Start training from score -1.396546

# %%
# Выбираем топ-50 признаков
top_features = importances.head(50).index.tolist()
X_selected = X[top_features]
X_test_selected = X_test[top_features]

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split

# %%
# Разделяем данные на обучающую и валидационную выборки для Optuna
X_train_optuna, X_valid_optuna, y_train_optuna, y_valid_optuna = train_test_split(
    X_selected, y, test_size=0.2, stratify=y, random_state=42
)

# %%
# Определение функции оптимизации для Optuna
def objective(trial):
    # Гиперпараметры для Random Forest
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 100, 300)
    rf_max_depth = trial.suggest_int('rf_max_depth', 5, 20)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    
    # Гиперпараметры для Gradient Boosting
    gb_n_estimators = trial.suggest_int('gb_n_estimators', 100, 350)
    gb_learning_rate = trial.suggest_loguniform('gb_learning_rate', 0.01, 0.3)
    gb_max_depth = trial.suggest_int('gb_max_depth', 3, 12)
    
    # Гиперпараметры для XGBoost
    xgb_n_estimators = trial.suggest_int('xgb_n_estimators', 100, 350)
    xgb_learning_rate = trial.suggest_loguniform('xgb_learning_rate', 0.01, 0.3)
    xgb_max_depth = trial.suggest_int('xgb_max_depth', 3, 12)
    
    # Гиперпараметры для CatBoost
    cat_iterations = trial.suggest_int('cat_iterations', 100, 350)
    cat_learning_rate = trial.suggest_loguniform('cat_learning_rate', 0.01, 0.3)
    cat_depth = trial.suggest_int('cat_depth', 3, 12)
    
    # Гиперпараметры для мета-модели (Logistic Regression)
    lr_C = trial.suggest_loguniform('lr_C', 1e-4, 10.0)
    
    # Определяем базовые модели с текущими гиперпараметрами
    base_learners = [
        ('rf', RandomForestClassifier(
            n_estimators=rf_n_estimators,
            max_depth=rf_max_depth,
            min_samples_split=rf_min_samples_split,
            random_state=42)),
        
        ('gb', GradientBoostingClassifier(
            n_estimators=gb_n_estimators,
            learning_rate=gb_learning_rate,
            max_depth=gb_max_depth,
            random_state=42)),
        
        ('xgb', XGBClassifier(
            n_estimators=xgb_n_estimators,
            learning_rate=xgb_learning_rate,
            max_depth=xgb_max_depth,
            use_label_encoder=False,
            eval_metric='logloss',
            random_state=42)),
        
        ('cat', CatBoostClassifier(
            iterations=cat_iterations,
            learning_rate=cat_learning_rate,
            depth=cat_depth,
            verbose=0,
            random_state=42))
    ]
    
    # Мета-модель
    meta_learner = LogisticRegression(
        C=lr_C,
        max_iter=1000,
        random_state=42)
    
    # Стэкинг-классификатор
    stacking_clf = StackingClassifier(
        estimators=base_learners,
        final_estimator=meta_learner,
        cv=5,
        n_jobs=-1
    )
    
    # Обучение модели на обучающей выборке
    stacking_clf.fit(X_train_optuna, y_train_optuna)
    
    # Предсказание на валидационной выборке
    y_pred_valid = stacking_clf.predict_proba(X_valid_optuna)[:, 1]
    
    # Оценка ROC AUC на валидационной выборке
    from sklearn.metrics import roc_auc_score
    roc_auc = roc_auc_score(y_valid_optuna, y_pred_valid)
    
    return -roc_auc  # Отрицательное значение для минимизации

# %%
# Запуск исследования Optuna
study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=42))
study.optimize(objective, n_trials=150, n_jobs=-1)

# Вывод наилучших гиперпараметров
print("Наилучшие гиперпараметры:")
for key, value in study.best_params.items():
    print(f"{key}: {value}")
# Out:
# [I 2024-09-22 13:10:10,596] A new study created in memory with name: no-name-932a78f3-5956-4264-b17f-437c062d796c
# [I 2024-09-22 13:13:49,982] Trial 1 finished with value: -0.8681226107463675 and parameters: {'rf_n_estimators': 272, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'gb_n_estimators': 201, 'gb_learning_rate': 0.28238434929594014, 'gb_max_depth': 5, 'xgb_n_estimators': 196, 'xgb_learning_rate': 0.034090268659426395, 'xgb_max_depth': 12, 'cat_iterations': 106, 'cat_learning_rate': 0.02637923510193758, 'cat_depth': 5, 'lr_C': 0.05194937873832614}. Best is trial 1 with value: -0.8681226107463675.
# [I 2024-09-22 13:13:50,001] Trial 20 finished with value: -0.869252649956869 and parameters: {'rf_n_estimators': 133, 'rf_max_depth': 13, 'rf_min_samples_split': 7, 'gb_n_estimators': 311, 'gb_learning_rate': 0.010460503737452524, 'gb_max_depth': 5, 'xgb_n_estimators': 249, 'xgb_learning_rate': 0.05134833293197279, 'xgb_max_depth': 9, 'cat_iterations': 162, 'cat_learning_rate': 0.1839505164517337, 'cat_depth': 4, 'lr_C': 0.0239692412899073}. Best is trial 20 with value: -0.869252649956869.
# [I 2024-09-22 13:14:23,094] Trial 9 finished with value: -0.8691408626126654 and parameters: {'rf_n_estimators': 226, 'rf_max_depth': 10, 'rf_min_samples_split': 2, 'gb_n_estimators': 105, 'gb_learning_rate': 0.0270561910252072, 'gb_max_depth': 4, 'xgb_n_estimators': 207, 'xgb_learning_rate': 0.015721585978613024, 'xgb_max_depth': 5, 'cat_iterations': 286, 'cat_learning_rate': 0.20250359712618535, 'cat_depth': 3, 'lr_C': 0.009519121973813612}. Best is trial 20 with value: -0.869252649956869.
# [I 2024-09-22 13:15:05,763] Trial 14 finished with value: -0.8694307751706305 and parameters: {'rf_n_estimators': 182, 'rf_max_depth': 12, 'rf_min_samples_split': 6, 'gb_n_estimators': 251, 'gb_learning_rate': 0.022742618676031744, 'gb_max_depth': 3, 'xgb_n_estimators': 308, 'xgb_learning_rate': 0.01117589177369289, 'xgb_max_depth': 9, 'cat_iterations': 291, 'cat_learning_rate': 0.01067746153298519, 'cat_depth': 4, 'lr_C': 0.02199368697727564}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:15:13,017] Trial 8 finished with value: -0.8692971812603094 and parameters: {'rf_n_estimators': 247, 'rf_max_depth': 12, 'rf_min_samples_split': 3, 'gb_n_estimators': 307, 'gb_learning_rate': 0.045545051223580615, 'gb_max_depth': 3, 'xgb_n_estimators': 225, 'xgb_learning_rate': 0.019410038077514475, 'xgb_max_depth': 8, 'cat_iterations': 249, 'cat_learning_rate': 0.10724175118371189, 'cat_depth': 8, 'lr_C': 0.14298034084250028}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:16:52,000] Trial 2 finished with value: -0.8679594058146864 and parameters: {'rf_n_estimators': 277, 'rf_max_depth': 18, 'rf_min_samples_split': 7, 'gb_n_estimators': 316, 'gb_learning_rate': 0.18848975826148834, 'gb_max_depth': 5, 'xgb_n_estimators': 124, 'xgb_learning_rate': 0.20444264483737945, 'xgb_max_depth': 6, 'cat_iterations': 343, 'cat_learning_rate': 0.016984695557210414, 'cat_depth': 8, 'lr_C': 0.006826512207176648}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:16:52,031] Trial 19 finished with value: -0.8667869011859557 and parameters: {'rf_n_estimators': 108, 'rf_max_depth': 15, 'rf_min_samples_split': 5, 'gb_n_estimators': 315, 'gb_learning_rate': 0.1424403236081179, 'gb_max_depth': 5, 'xgb_n_estimators': 110, 'xgb_learning_rate': 0.13840533020614432, 'xgb_max_depth': 6, 'cat_iterations': 165, 'cat_learning_rate': 0.11621796152000662, 'cat_depth': 9, 'lr_C': 0.002078695846802984}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:16:52,260] Trial 22 finished with value: -0.8691509624959199 and parameters: {'rf_n_estimators': 176, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'gb_n_estimators': 146, 'gb_learning_rate': 0.23162319862226977, 'gb_max_depth': 5, 'xgb_n_estimators': 234, 'xgb_learning_rate': 0.16811182709096642, 'xgb_max_depth': 12, 'cat_iterations': 153, 'cat_learning_rate': 0.195900335359953, 'cat_depth': 4, 'lr_C': 0.0014333132740186887}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:16:52,528] Trial 11 finished with value: -0.8671511856115226 and parameters: {'rf_n_estimators': 238, 'rf_max_depth': 18, 'rf_min_samples_split': 2, 'gb_n_estimators': 107, 'gb_learning_rate': 0.1508594805522207, 'gb_max_depth': 11, 'xgb_n_estimators': 173, 'xgb_learning_rate': 0.014627214424932174, 'xgb_max_depth': 10, 'cat_iterations': 244, 'cat_learning_rate': 0.014462804910224896, 'cat_depth': 7, 'lr_C': 0.00037071567150654067}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:16:52,602] Trial 6 finished with value: -0.8672820250082292 and parameters: {'rf_n_estimators': 252, 'rf_max_depth': 11, 'rf_min_samples_split': 6, 'gb_n_estimators': 300, 'gb_learning_rate': 0.07440703326418771, 'gb_max_depth': 6, 'xgb_n_estimators': 321, 'xgb_learning_rate': 0.266653293951076, 'xgb_max_depth': 8, 'cat_iterations': 257, 'cat_learning_rate': 0.05642345274156609, 'cat_depth': 9, 'lr_C': 0.004541874098909812}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:16:52,742] Trial 23 finished with value: -0.8685917962321008 and parameters: {'rf_n_estimators': 217, 'rf_max_depth': 18, 'rf_min_samples_split': 2, 'gb_n_estimators': 115, 'gb_learning_rate': 0.05455840460880287, 'gb_max_depth': 7, 'xgb_n_estimators': 250, 'xgb_learning_rate': 0.021585774795584465, 'xgb_max_depth': 8, 'cat_iterations': 315, 'cat_learning_rate': 0.21975688939252191, 'cat_depth': 8, 'lr_C': 0.07413566595092554}. Best is trial 14 with value: -0.8694307751706305.
# [I 2024-09-22 13:16:53,306] Trial 16 finished with value: -0.8702780176500051 and parameters: {'rf_n_estimators': 278, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 103, 'gb_learning_rate': 0.13775392769001793, 'gb_max_depth': 6, 'xgb_n_estimators': 335, 'xgb_learning_rate': 0.059236729039509016, 'xgb_max_depth': 3, 'cat_iterations': 161, 'cat_learning_rate': 0.011217773277915715, 'cat_depth': 8, 'lr_C': 4.854893903372788}. Best is trial 16 with value: -0.8702780176500051.
# [I 2024-09-22 13:16:53,327] Trial 15 finished with value: -0.8668858341332899 and parameters: {'rf_n_estimators': 287, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'gb_n_estimators': 333, 'gb_learning_rate': 0.1478494831458938, 'gb_max_depth': 3, 'xgb_n_estimators': 296, 'xgb_learning_rate': 0.23727388455207737, 'xgb_max_depth': 5, 'cat_iterations': 152, 'cat_learning_rate': 0.07661808687747004, 'cat_depth': 11, 'lr_C': 0.01648002027421117}. Best is trial 16 with value: -0.8702780176500051.
# [I 2024-09-22 13:17:49,474] Trial 4 finished with value: -0.866917511039861 and parameters: {'rf_n_estimators': 214, 'rf_max_depth': 19, 'rf_min_samples_split': 8, 'gb_n_estimators': 320, 'gb_learning_rate': 0.2295829849202025, 'gb_max_depth': 6, 'xgb_n_estimators': 260, 'xgb_learning_rate': 0.02243611539446958, 'xgb_max_depth': 8, 'cat_iterations': 276, 'cat_learning_rate': 0.07268912333938524, 'cat_depth': 8, 'lr_C': 0.0024092365104309618}. Best is trial 16 with value: -0.8702780176500051.
# [I 2024-09-22 13:17:58,612] Trial 3 finished with value: -0.8714477677651207 and parameters: {'rf_n_estimators': 194, 'rf_max_depth': 11, 'rf_min_samples_split': 6, 'gb_n_estimators': 122, 'gb_learning_rate': 0.025290593018288114, 'gb_max_depth': 7, 'xgb_n_estimators': 322, 'xgb_learning_rate': 0.02210302892159263, 'xgb_max_depth': 7, 'cat_iterations': 291, 'cat_learning_rate': 0.03097514012437246, 'cat_depth': 10, 'lr_C': 4.123072395604524}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:20:12,335] Trial 12 finished with value: -0.8672912067202787 and parameters: {'rf_n_estimators': 264, 'rf_max_depth': 9, 'rf_min_samples_split': 7, 'gb_n_estimators': 224, 'gb_learning_rate': 0.05196087799782389, 'gb_max_depth': 7, 'xgb_n_estimators': 249, 'xgb_learning_rate': 0.012878444366254209, 'xgb_max_depth': 12, 'cat_iterations': 287, 'cat_learning_rate': 0.22148556649617474, 'cat_depth': 11, 'lr_C': 0.02540697787303589}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:20:28,545] Trial 0 finished with value: -0.8712159295358691 and parameters: {'rf_n_estimators': 164, 'rf_max_depth': 13, 'rf_min_samples_split': 8, 'gb_n_estimators': 139, 'gb_learning_rate': 0.04944180065793942, 'gb_max_depth': 5, 'xgb_n_estimators': 229, 'xgb_learning_rate': 0.010080182215971222, 'xgb_max_depth': 6, 'cat_iterations': 321, 'cat_learning_rate': 0.03101081039502732, 'cat_depth': 10, 'lr_C': 0.16415765171240035}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:21:29,852] Trial 17 finished with value: -0.8660925342122068 and parameters: {'rf_n_estimators': 175, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'gb_n_estimators': 323, 'gb_learning_rate': 0.17243989389191527, 'gb_max_depth': 3, 'xgb_n_estimators': 268, 'xgb_learning_rate': 0.052897044345570576, 'xgb_max_depth': 9, 'cat_iterations': 280, 'cat_learning_rate': 0.1538875757067399, 'cat_depth': 11, 'lr_C': 0.009012053084442804}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:22:06,766] Trial 21 finished with value: -0.8680948360674178 and parameters: {'rf_n_estimators': 127, 'rf_max_depth': 14, 'rf_min_samples_split': 6, 'gb_n_estimators': 343, 'gb_learning_rate': 0.04037827015176244, 'gb_max_depth': 9, 'xgb_n_estimators': 182, 'xgb_learning_rate': 0.02722120822689079, 'xgb_max_depth': 11, 'cat_iterations': 105, 'cat_learning_rate': 0.058954409009018306, 'cat_depth': 8, 'lr_C': 0.0165919296033033}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:22:08,357] Trial 13 finished with value: -0.8703581280876375 and parameters: {'rf_n_estimators': 219, 'rf_max_depth': 14, 'rf_min_samples_split': 2, 'gb_n_estimators': 293, 'gb_learning_rate': 0.2656552113278775, 'gb_max_depth': 11, 'xgb_n_estimators': 308, 'xgb_learning_rate': 0.09471358927647852, 'xgb_max_depth': 3, 'cat_iterations': 104, 'cat_learning_rate': 0.03173522745432795, 'cat_depth': 4, 'lr_C': 0.006247248459610915}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:22:30,988] Trial 5 finished with value: -0.8712409497012039 and parameters: {'rf_n_estimators': 168, 'rf_max_depth': 12, 'rf_min_samples_split': 3, 'gb_n_estimators': 306, 'gb_learning_rate': 0.011091103919467967, 'gb_max_depth': 6, 'xgb_n_estimators': 216, 'xgb_learning_rate': 0.08676671709683004, 'xgb_max_depth': 6, 'cat_iterations': 272, 'cat_learning_rate': 0.01840904550197916, 'cat_depth': 12, 'lr_C': 0.011397968957013753}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:23:22,649] Trial 10 finished with value: -0.8681974416995717 and parameters: {'rf_n_estimators': 116, 'rf_max_depth': 10, 'rf_min_samples_split': 2, 'gb_n_estimators': 321, 'gb_learning_rate': 0.018591953872671707, 'gb_max_depth': 11, 'xgb_n_estimators': 215, 'xgb_learning_rate': 0.2203666838748564, 'xgb_max_depth': 8, 'cat_iterations': 110, 'cat_learning_rate': 0.16054066299659484, 'cat_depth': 10, 'lr_C': 0.5985972214236086}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:23:24,371] Trial 7 finished with value: -0.8695742394214052 and parameters: {'rf_n_estimators': 294, 'rf_max_depth': 13, 'rf_min_samples_split': 7, 'gb_n_estimators': 100, 'gb_learning_rate': 0.016428909355462217, 'gb_max_depth': 7, 'xgb_n_estimators': 288, 'xgb_learning_rate': 0.028039389901630137, 'xgb_max_depth': 10, 'cat_iterations': 302, 'cat_learning_rate': 0.06171126822042598, 'cat_depth': 11, 'lr_C': 0.011476415483570103}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:24:26,143] Trial 18 finished with value: -0.8667095452619382 and parameters: {'rf_n_estimators': 198, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'gb_n_estimators': 335, 'gb_learning_rate': 0.023959057741472386, 'gb_max_depth': 11, 'xgb_n_estimators': 283, 'xgb_learning_rate': 0.07185101216088317, 'xgb_max_depth': 12, 'cat_iterations': 267, 'cat_learning_rate': 0.12870115962410636, 'cat_depth': 11, 'lr_C': 0.0011305535038435733}. Best is trial 3 with value: -0.8714477677651207.
# [I 2024-09-22 13:24:48,349] Trial 31 finished with value: -0.8715388962572127 and parameters: {'rf_n_estimators': 235, 'rf_max_depth': 11, 'rf_min_samples_split': 2, 'gb_n_estimators': 154, 'gb_learning_rate': 0.021608215539628054, 'gb_max_depth': 6, 'xgb_n_estimators': 275, 'xgb_learning_rate': 0.012137981047622393, 'xgb_max_depth': 11, 'cat_iterations': 111, 'cat_learning_rate': 0.06176467616085627, 'cat_depth': 10, 'lr_C': 0.6328369665977503}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:26:23,907] Trial 24 finished with value: -0.868185275931106 and parameters: {'rf_n_estimators': 265, 'rf_max_depth': 19, 'rf_min_samples_split': 7, 'gb_n_estimators': 164, 'gb_learning_rate': 0.17133122792677422, 'gb_max_depth': 11, 'xgb_n_estimators': 194, 'xgb_learning_rate': 0.02550902719567698, 'xgb_max_depth': 11, 'cat_iterations': 217, 'cat_learning_rate': 0.09086820338124545, 'cat_depth': 3, 'lr_C': 0.0009290870967364601}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:27:21,766] Trial 26 finished with value: -0.8684823043159096 and parameters: {'rf_n_estimators': 291, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'gb_n_estimators': 251, 'gb_learning_rate': 0.06317612466868458, 'gb_max_depth': 9, 'xgb_n_estimators': 247, 'xgb_learning_rate': 0.11053282948568334, 'xgb_max_depth': 10, 'cat_iterations': 332, 'cat_learning_rate': 0.013676162572633235, 'cat_depth': 7, 'lr_C': 0.008691498398405875}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:27:21,809] Trial 30 finished with value: -0.868696467749466 and parameters: {'rf_n_estimators': 223, 'rf_max_depth': 10, 'rf_min_samples_split': 2, 'gb_n_estimators': 136, 'gb_learning_rate': 0.2693189569600523, 'gb_max_depth': 12, 'xgb_n_estimators': 289, 'xgb_learning_rate': 0.01953842707645003, 'xgb_max_depth': 6, 'cat_iterations': 313, 'cat_learning_rate': 0.10294062776219533, 'cat_depth': 9, 'lr_C': 1.4468325334544017}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:29:51,899] Trial 28 finished with value: -0.8710993217928396 and parameters: {'rf_n_estimators': 186, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'gb_n_estimators': 247, 'gb_learning_rate': 0.08117094537455964, 'gb_max_depth': 10, 'xgb_n_estimators': 130, 'xgb_learning_rate': 0.15014895301626988, 'xgb_max_depth': 3, 'cat_iterations': 324, 'cat_learning_rate': 0.069705976650041, 'cat_depth': 3, 'lr_C': 0.01709390108002649}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:29:53,145] Trial 29 finished with value: -0.8689003017569665 and parameters: {'rf_n_estimators': 106, 'rf_max_depth': 12, 'rf_min_samples_split': 4, 'gb_n_estimators': 291, 'gb_learning_rate': 0.076117136392755, 'gb_max_depth': 9, 'xgb_n_estimators': 328, 'xgb_learning_rate': 0.010952491508711772, 'xgb_max_depth': 3, 'cat_iterations': 346, 'cat_learning_rate': 0.19495842176463335, 'cat_depth': 4, 'lr_C': 4.075078398558011}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:29:53,952] Trial 36 finished with value: -0.8713375872205258 and parameters: {'rf_n_estimators': 179, 'rf_max_depth': 15, 'rf_min_samples_split': 10, 'gb_n_estimators': 248, 'gb_learning_rate': 0.017255068562723463, 'gb_max_depth': 8, 'xgb_n_estimators': 345, 'xgb_learning_rate': 0.09266426931996474, 'xgb_max_depth': 3, 'cat_iterations': 207, 'cat_learning_rate': 0.02741323275338468, 'cat_depth': 6, 'lr_C': 3.0179434568076395}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:30:25,630] Trial 35 finished with value: -0.8705252352469398 and parameters: {'rf_n_estimators': 165, 'rf_max_depth': 15, 'rf_min_samples_split': 10, 'gb_n_estimators': 250, 'gb_learning_rate': 0.021350436025794187, 'gb_max_depth': 9, 'xgb_n_estimators': 345, 'xgb_learning_rate': 0.08012606794345582, 'xgb_max_depth': 3, 'cat_iterations': 207, 'cat_learning_rate': 0.027100602475497258, 'cat_depth': 6, 'lr_C': 3.035367405259558}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:30:26,589] Trial 27 finished with value: -0.8687373263680865 and parameters: {'rf_n_estimators': 246, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'gb_n_estimators': 338, 'gb_learning_rate': 0.02011318182017554, 'gb_max_depth': 9, 'xgb_n_estimators': 230, 'xgb_learning_rate': 0.057167336379416275, 'xgb_max_depth': 7, 'cat_iterations': 152, 'cat_learning_rate': 0.06080488914539679, 'cat_depth': 11, 'lr_C': 0.006113279605286314}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:31:23,210] Trial 37 finished with value: -0.8697073742461241 and parameters: {'rf_n_estimators': 178, 'rf_max_depth': 14, 'rf_min_samples_split': 10, 'gb_n_estimators': 249, 'gb_learning_rate': 0.016707580799868595, 'gb_max_depth': 9, 'xgb_n_estimators': 349, 'xgb_learning_rate': 0.08615140375947639, 'xgb_max_depth': 3, 'cat_iterations': 202, 'cat_learning_rate': 0.010317230802309786, 'cat_depth': 6, 'lr_C': 9.10994820805295}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:31:24,683] Trial 32 finished with value: -0.8659201475684761 and parameters: {'rf_n_estimators': 162, 'rf_max_depth': 15, 'rf_min_samples_split': 9, 'gb_n_estimators': 317, 'gb_learning_rate': 0.0567621377843849, 'gb_max_depth': 10, 'xgb_n_estimators': 125, 'xgb_learning_rate': 0.08694711570566063, 'xgb_max_depth': 10, 'cat_iterations': 248, 'cat_learning_rate': 0.22079708597543296, 'cat_depth': 9, 'lr_C': 4.376632330009319}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:31:47,285] Trial 39 finished with value: -0.8708612859079543 and parameters: {'rf_n_estimators': 156, 'rf_max_depth': 15, 'rf_min_samples_split': 10, 'gb_n_estimators': 158, 'gb_learning_rate': 0.09348209912871812, 'gb_max_depth': 9, 'xgb_n_estimators': 347, 'xgb_learning_rate': 0.0918435171340284, 'xgb_max_depth': 3, 'cat_iterations': 109, 'cat_learning_rate': 0.02835815056838222, 'cat_depth': 12, 'lr_C': 9.406439291783332}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:32:33,862] Trial 25 finished with value: -0.8690582272042191 and parameters: {'rf_n_estimators': 188, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'gb_n_estimators': 264, 'gb_learning_rate': 0.07180927465650633, 'gb_max_depth': 12, 'xgb_n_estimators': 115, 'xgb_learning_rate': 0.05880436863125362, 'xgb_max_depth': 6, 'cat_iterations': 114, 'cat_learning_rate': 0.19896713126268856, 'cat_depth': 11, 'lr_C': 0.013221527938541443}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:35:07,847] Trial 40 finished with value: -0.870910867153022 and parameters: {'rf_n_estimators': 150, 'rf_max_depth': 15, 'rf_min_samples_split': 10, 'gb_n_estimators': 160, 'gb_learning_rate': 0.024315615876449544, 'gb_max_depth': 10, 'xgb_n_estimators': 153, 'xgb_learning_rate': 0.041361747046021816, 'xgb_max_depth': 3, 'cat_iterations': 346, 'cat_learning_rate': 0.03372457258491802, 'cat_depth': 10, 'lr_C': 1.4133183782282208}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:35:57,660] Trial 34 finished with value: -0.8695623031957407 and parameters: {'rf_n_estimators': 180, 'rf_max_depth': 14, 'rf_min_samples_split': 4, 'gb_n_estimators': 249, 'gb_learning_rate': 0.023364634462651596, 'gb_max_depth': 3, 'xgb_n_estimators': 335, 'xgb_learning_rate': 0.011024874546281824, 'xgb_max_depth': 3, 'cat_iterations': 206, 'cat_learning_rate': 0.05354666544171389, 'cat_depth': 12, 'lr_C': 0.9037196069311201}. Best is trial 31 with value: -0.8715388962572127.
# [I 2024-09-22 13:36:56,415] Trial 38 finished with value: -0.871594675157914 and parameters: {'rf_n_estimators': 158, 'rf_max_depth': 14, 'rf_min_samples_split': 10, 'gb_n_estimators': 154, 'gb_learning_rate': 0.09420174208348332, 'gb_max_depth': 9, 'xgb_n_estimators': 335, 'xgb_learning_rate': 0.09173717420932387, 'xgb_max_depth': 3, 'cat_iterations': 204, 'cat_learning_rate': 0.031360405120150835, 'cat_depth': 12, 'lr_C': 5.313807186247137}. Best is trial 38 with value: -0.871594675157914.
# [I 2024-09-22 13:54:46,656] Trial 41 finished with value: -0.8707003764042855 and parameters: {'rf_n_estimators': 149, 'rf_max_depth': 15, 'rf_min_samples_split': 10, 'gb_n_estimators': 161, 'gb_learning_rate': 0.02576968641241501, 'gb_max_depth': 9, 'xgb_n_estimators': 156, 'xgb_learning_rate': 0.03298184404870096, 'xgb_max_depth': 3, 'cat_iterations': 349, 'cat_learning_rate': 0.033295847958996205, 'cat_depth': 12, 'lr_C': 1.5445947132952547}. Best is trial 38 with value: -0.871594675157914.
# [I 2024-09-22 13:57:24,977] Trial 33 finished with value: -0.872420570156773 and parameters: {'rf_n_estimators': 177, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'gb_n_estimators': 249, 'gb_learning_rate': 0.014558979708316613, 'gb_max_depth': 9, 'xgb_n_estimators': 349, 'xgb_learning_rate': 0.010495089275623674, 'xgb_max_depth': 3, 'cat_iterations': 347, 'cat_learning_rate': 0.03505955989906093, 'cat_depth': 12, 'lr_C': 3.9214510817910027}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 13:59:46,484] Trial 48 finished with value: -0.8696199184388518 and parameters: {'rf_n_estimators': 152, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'gb_n_estimators': 173, 'gb_learning_rate': 0.010191205976157648, 'gb_max_depth': 9, 'xgb_n_estimators': 344, 'xgb_learning_rate': 0.041402836879398275, 'xgb_max_depth': 7, 'cat_iterations': 204, 'cat_learning_rate': 0.039949176517608286, 'cat_depth': 12, 'lr_C': 2.342215006467879}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:02:49,870] Trial 49 finished with value: -0.8701097627766966 and parameters: {'rf_n_estimators': 150, 'rf_max_depth': 15, 'rf_min_samples_split': 4, 'gb_n_estimators': 185, 'gb_learning_rate': 0.010018088922353873, 'gb_max_depth': 9, 'xgb_n_estimators': 347, 'xgb_learning_rate': 0.03792835050726087, 'xgb_max_depth': 7, 'cat_iterations': 219, 'cat_learning_rate': 0.042129560994547004, 'cat_depth': 12, 'lr_C': 9.834944871444742}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:04:05,057] Trial 51 finished with value: -0.8706661745269009 and parameters: {'rf_n_estimators': 159, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'gb_n_estimators': 181, 'gb_learning_rate': 0.01230896995308629, 'gb_max_depth': 8, 'xgb_n_estimators': 348, 'xgb_learning_rate': 0.03634325197708311, 'xgb_max_depth': 7, 'cat_iterations': 208, 'cat_learning_rate': 0.021973199883211184, 'cat_depth': 12, 'lr_C': 3.9435289606226545}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:05:08,383] Trial 63 finished with value: -0.8705233989045299 and parameters: {'rf_n_estimators': 206, 'rf_max_depth': 17, 'rf_min_samples_split': 9, 'gb_n_estimators': 188, 'gb_learning_rate': 0.031703202038676354, 'gb_max_depth': 8, 'xgb_n_estimators': 311, 'xgb_learning_rate': 0.03489232299094286, 'xgb_max_depth': 4, 'cat_iterations': 180, 'cat_learning_rate': 0.043089709296790936, 'cat_depth': 6, 'lr_C': 0.35316308575231004}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:06:32,079] Trial 44 finished with value: -0.8688858405604885 and parameters: {'rf_n_estimators': 153, 'rf_max_depth': 16, 'rf_min_samples_split': 10, 'gb_n_estimators': 156, 'gb_learning_rate': 0.010413035818966854, 'gb_max_depth': 9, 'xgb_n_estimators': 149, 'xgb_learning_rate': 0.08900401266872991, 'xgb_max_depth': 6, 'cat_iterations': 322, 'cat_learning_rate': 0.03343512079529383, 'cat_depth': 12, 'lr_C': 0.5258866951328994}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:07:30,869] Trial 50 finished with value: -0.868795171153999 and parameters: {'rf_n_estimators': 152, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'gb_n_estimators': 184, 'gb_learning_rate': 0.010888891538263158, 'gb_max_depth': 9, 'xgb_n_estimators': 349, 'xgb_learning_rate': 0.04293662206265327, 'xgb_max_depth': 5, 'cat_iterations': 209, 'cat_learning_rate': 0.042258863002176, 'cat_depth': 12, 'lr_C': 9.176328060105966}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:09:00,569] Trial 52 finished with value: -0.8702286659477386 and parameters: {'rf_n_estimators': 148, 'rf_max_depth': 15, 'rf_min_samples_split': 4, 'gb_n_estimators': 177, 'gb_learning_rate': 0.010644552171023669, 'gb_max_depth': 8, 'xgb_n_estimators': 339, 'xgb_learning_rate': 0.010018090530060409, 'xgb_max_depth': 7, 'cat_iterations': 214, 'cat_learning_rate': 0.03593512553870417, 'cat_depth': 12, 'lr_C': 8.08213495546909}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:09:06,389] Trial 60 finished with value: -0.8704361726400589 and parameters: {'rf_n_estimators': 197, 'rf_max_depth': 17, 'rf_min_samples_split': 3, 'gb_n_estimators': 187, 'gb_learning_rate': 0.011264118913174418, 'gb_max_depth': 8, 'xgb_n_estimators': 314, 'xgb_learning_rate': 0.12126800235059698, 'xgb_max_depth': 4, 'cat_iterations': 193, 'cat_learning_rate': 0.03817330847668523, 'cat_depth': 12, 'lr_C': 0.4971846970547375}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:09:57,138] Trial 54 finished with value: -0.8699157991096494 and parameters: {'rf_n_estimators': 159, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'gb_n_estimators': 169, 'gb_learning_rate': 0.010419567326013877, 'gb_max_depth': 8, 'xgb_n_estimators': 346, 'xgb_learning_rate': 0.08017827167971824, 'xgb_max_depth': 4, 'cat_iterations': 197, 'cat_learning_rate': 0.04152250169042062, 'cat_depth': 12, 'lr_C': 0.6211539409450332}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:35,375] Trial 55 finished with value: -0.8700211592554182 and parameters: {'rf_n_estimators': 144, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'gb_n_estimators': 193, 'gb_learning_rate': 0.012881364437636475, 'gb_max_depth': 8, 'xgb_n_estimators': 346, 'xgb_learning_rate': 0.039312568019072396, 'xgb_max_depth': 7, 'cat_iterations': 192, 'cat_learning_rate': 0.04042056425610223, 'cat_depth': 12, 'lr_C': 0.6450942522998743}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:51,396] Trial 45 finished with value: -0.8696357568921373 and parameters: {'rf_n_estimators': 153, 'rf_max_depth': 15, 'rf_min_samples_split': 4, 'gb_n_estimators': 164, 'gb_learning_rate': 0.011186974953083632, 'gb_max_depth': 9, 'xgb_n_estimators': 145, 'xgb_learning_rate': 0.10152575251593102, 'xgb_max_depth': 6, 'cat_iterations': 332, 'cat_learning_rate': 0.032442707387123626, 'cat_depth': 12, 'lr_C': 4.975696315913492}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:52,931] Trial 58 finished with value: -0.8700289637106604 and parameters: {'rf_n_estimators': 148, 'rf_max_depth': 16, 'rf_min_samples_split': 3, 'gb_n_estimators': 186, 'gb_learning_rate': 0.011967431237125096, 'gb_max_depth': 8, 'xgb_n_estimators': 313, 'xgb_learning_rate': 0.04369573261666081, 'xgb_max_depth': 5, 'cat_iterations': 187, 'cat_learning_rate': 0.0424743484133321, 'cat_depth': 12, 'lr_C': 0.5045829218912673}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:52,977] Trial 53 finished with value: -0.8700094525725549 and parameters: {'rf_n_estimators': 157, 'rf_max_depth': 5, 'rf_min_samples_split': 4, 'gb_n_estimators': 171, 'gb_learning_rate': 0.010480121635249876, 'gb_max_depth': 8, 'xgb_n_estimators': 150, 'xgb_learning_rate': 0.041522164392198, 'xgb_max_depth': 7, 'cat_iterations': 218, 'cat_learning_rate': 0.03596106289696025, 'cat_depth': 12, 'lr_C': 0.6251548361419001}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:54,349] Trial 43 finished with value: -0.8695368239448031 and parameters: {'rf_n_estimators': 151, 'rf_max_depth': 16, 'rf_min_samples_split': 10, 'gb_n_estimators': 166, 'gb_learning_rate': 0.08751662277161934, 'gb_max_depth': 8, 'xgb_n_estimators': 146, 'xgb_learning_rate': 0.037332416735657806, 'xgb_max_depth': 6, 'cat_iterations': 350, 'cat_learning_rate': 0.03413387149596354, 'cat_depth': 12, 'lr_C': 1.1596028747152027}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:54,488] Trial 59 finished with value: -0.8708672540207866 and parameters: {'rf_n_estimators': 199, 'rf_max_depth': 16, 'rf_min_samples_split': 3, 'gb_n_estimators': 180, 'gb_learning_rate': 0.013819427158344008, 'gb_max_depth': 6, 'xgb_n_estimators': 316, 'xgb_learning_rate': 0.041453854809202724, 'xgb_max_depth': 4, 'cat_iterations': 187, 'cat_learning_rate': 0.03985613873706347, 'cat_depth': 12, 'lr_C': 0.5348387627477901}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:55,301] Trial 46 finished with value: -0.8694064436336993 and parameters: {'rf_n_estimators': 152, 'rf_max_depth': 16, 'rf_min_samples_split': 10, 'gb_n_estimators': 154, 'gb_learning_rate': 0.08717216086723396, 'gb_max_depth': 9, 'xgb_n_estimators': 147, 'xgb_learning_rate': 0.03880133690056941, 'xgb_max_depth': 6, 'cat_iterations': 339, 'cat_learning_rate': 0.029456816699659428, 'cat_depth': 12, 'lr_C': 7.263478806679295}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:55,313] Trial 57 finished with value: -0.871508367064648 and parameters: {'rf_n_estimators': 143, 'rf_max_depth': 16, 'rf_min_samples_split': 3, 'gb_n_estimators': 183, 'gb_learning_rate': 0.012497380848056905, 'gb_max_depth': 8, 'xgb_n_estimators': 314, 'xgb_learning_rate': 0.04013012686433464, 'xgb_max_depth': 5, 'cat_iterations': 235, 'cat_learning_rate': 0.04024092638091739, 'cat_depth': 12, 'lr_C': 0.7874925480891501}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:55,530] Trial 42 finished with value: -0.8671605968663735 and parameters: {'rf_n_estimators': 153, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'gb_n_estimators': 166, 'gb_learning_rate': 0.01513058797602686, 'gb_max_depth': 9, 'xgb_n_estimators': 148, 'xgb_learning_rate': 0.01039857695507056, 'xgb_max_depth': 3, 'cat_iterations': 347, 'cat_learning_rate': 0.035540534286487714, 'cat_depth': 12, 'lr_C': 1.0946072910169005}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:55,732] Trial 56 finished with value: -0.8706992286902793 and parameters: {'rf_n_estimators': 147, 'rf_max_depth': 16, 'rf_min_samples_split': 3, 'gb_n_estimators': 187, 'gb_learning_rate': 0.012677891026133335, 'gb_max_depth': 8, 'xgb_n_estimators': 348, 'xgb_learning_rate': 0.038338609461241464, 'xgb_max_depth': 5, 'cat_iterations': 191, 'cat_learning_rate': 0.03846925623489425, 'cat_depth': 12, 'lr_C': 0.7161944972908132}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:11:56,547] Trial 62 finished with value: -0.8709487417152266 and parameters: {'rf_n_estimators': 209, 'rf_max_depth': 17, 'rf_min_samples_split': 3, 'gb_n_estimators': 196, 'gb_learning_rate': 0.012356026168469205, 'gb_max_depth': 8, 'xgb_n_estimators': 269, 'xgb_learning_rate': 0.03699585668789322, 'xgb_max_depth': 5, 'cat_iterations': 185, 'cat_learning_rate': 0.020565058935542734, 'cat_depth': 12, 'lr_C': 0.21522005390034638}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:12:33,575] Trial 61 finished with value: -0.8699155695668481 and parameters: {'rf_n_estimators': 203, 'rf_max_depth': 17, 'rf_min_samples_split': 3, 'gb_n_estimators': 193, 'gb_learning_rate': 0.012055211457599812, 'gb_max_depth': 8, 'xgb_n_estimators': 313, 'xgb_learning_rate': 0.04228824431387066, 'xgb_max_depth': 5, 'cat_iterations': 187, 'cat_learning_rate': 0.04224412614154049, 'cat_depth': 12, 'lr_C': 0.40733794864018613}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:12:43,033] Trial 47 finished with value: -0.8695430216004366 and parameters: {'rf_n_estimators': 152, 'rf_max_depth': 16, 'rf_min_samples_split': 10, 'gb_n_estimators': 157, 'gb_learning_rate': 0.08516134458467668, 'gb_max_depth': 9, 'xgb_n_estimators': 350, 'xgb_learning_rate': 0.010258356209459172, 'xgb_max_depth': 6, 'cat_iterations': 336, 'cat_learning_rate': 0.034682042596657275, 'cat_depth': 12, 'lr_C': 6.2532011056761325}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:13:08,422] Trial 64 finished with value: -0.8697408874951051 and parameters: {'rf_n_estimators': 197, 'rf_max_depth': 17, 'rf_min_samples_split': 3, 'gb_n_estimators': 180, 'gb_learning_rate': 0.01273440486861056, 'gb_max_depth': 8, 'xgb_n_estimators': 311, 'xgb_learning_rate': 0.1178535550251713, 'xgb_max_depth': 4, 'cat_iterations': 189, 'cat_learning_rate': 0.021511502344245273, 'cat_depth': 10, 'lr_C': 0.378907204754713}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:13:17,786] Trial 65 finished with value: -0.8699584940706799 and parameters: {'rf_n_estimators': 197, 'rf_max_depth': 17, 'rf_min_samples_split': 9, 'gb_n_estimators': 185, 'gb_learning_rate': 0.012934327463159132, 'gb_max_depth': 8, 'xgb_n_estimators': 317, 'xgb_learning_rate': 0.015683027573556683, 'xgb_max_depth': 4, 'cat_iterations': 130, 'cat_learning_rate': 0.04206148913322681, 'cat_depth': 10, 'lr_C': 0.19757113050854164}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:16:23,230] Trial 66 finished with value: -0.8705279897605547 and parameters: {'rf_n_estimators': 209, 'rf_max_depth': 17, 'rf_min_samples_split': 9, 'gb_n_estimators': 218, 'gb_learning_rate': 0.013285801303641036, 'gb_max_depth': 8, 'xgb_n_estimators': 316, 'xgb_learning_rate': 0.016559721315334994, 'xgb_max_depth': 4, 'cat_iterations': 184, 'cat_learning_rate': 0.020920705249099263, 'cat_depth': 10, 'lr_C': 0.37146010549924185}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:16:30,627] Trial 67 finished with value: -0.8704102343035189 and parameters: {'rf_n_estimators': 205, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 211, 'gb_learning_rate': 0.012774488677438292, 'gb_max_depth': 8, 'xgb_n_estimators': 317, 'xgb_learning_rate': 0.015721862076661004, 'xgb_max_depth': 4, 'cat_iterations': 181, 'cat_learning_rate': 0.023704304470308864, 'cat_depth': 10, 'lr_C': 0.29914914142060706}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:16:54,417] Trial 68 finished with value: -0.8704439770953012 and parameters: {'rf_n_estimators': 207, 'rf_max_depth': 17, 'rf_min_samples_split': 9, 'gb_n_estimators': 206, 'gb_learning_rate': 0.033365542911377014, 'gb_max_depth': 8, 'xgb_n_estimators': 319, 'xgb_learning_rate': 0.01620451665581912, 'xgb_max_depth': 4, 'cat_iterations': 234, 'cat_learning_rate': 0.021575985048345684, 'cat_depth': 10, 'lr_C': 0.43281609104568824}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:18:49,662] Trial 73 finished with value: -0.8709356577755558 and parameters: {'rf_n_estimators': 232, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 212, 'gb_learning_rate': 0.030688704395236393, 'gb_max_depth': 7, 'xgb_n_estimators': 323, 'xgb_learning_rate': 0.014305642576560126, 'xgb_max_depth': 4, 'cat_iterations': 121, 'cat_learning_rate': 0.021852576744209096, 'cat_depth': 10, 'lr_C': 0.2696983281731508}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:19:00,535] Trial 69 finished with value: -0.8707770436998994 and parameters: {'rf_n_estimators': 200, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 216, 'gb_learning_rate': 0.01339999907286295, 'gb_max_depth': 8, 'xgb_n_estimators': 327, 'xgb_learning_rate': 0.01551791232433743, 'xgb_max_depth': 4, 'cat_iterations': 235, 'cat_learning_rate': 0.0226233172231705, 'cat_depth': 10, 'lr_C': 0.33371041695525805}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:19:02,705] Trial 70 finished with value: -0.8712127159366516 and parameters: {'rf_n_estimators': 192, 'rf_max_depth': 13, 'rf_min_samples_split': 9, 'gb_n_estimators': 217, 'gb_learning_rate': 0.013451122192491052, 'gb_max_depth': 8, 'xgb_n_estimators': 320, 'xgb_learning_rate': 0.017066715179425002, 'xgb_max_depth': 4, 'cat_iterations': 237, 'cat_learning_rate': 0.29568103897713927, 'cat_depth': 10, 'lr_C': 0.2163394041991535}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:19:06,399] Trial 71 finished with value: -0.8701689848194164 and parameters: {'rf_n_estimators': 200, 'rf_max_depth': 20, 'rf_min_samples_split': 9, 'gb_n_estimators': 209, 'gb_learning_rate': 0.014350397195415664, 'gb_max_depth': 8, 'xgb_n_estimators': 317, 'xgb_learning_rate': 0.0158314878088663, 'xgb_max_depth': 4, 'cat_iterations': 232, 'cat_learning_rate': 0.02293494194724948, 'cat_depth': 10, 'lr_C': 0.188776293989384}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:19:10,541] Trial 74 finished with value: -0.8710013070167102 and parameters: {'rf_n_estimators': 208, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 212, 'gb_learning_rate': 0.014725300590261751, 'gb_max_depth': 6, 'xgb_n_estimators': 327, 'xgb_learning_rate': 0.013402683830360666, 'xgb_max_depth': 4, 'cat_iterations': 233, 'cat_learning_rate': 0.02175120758814444, 'cat_depth': 10, 'lr_C': 0.26519502938840606}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:19:11,506] Trial 72 finished with value: -0.8705220216477225 and parameters: {'rf_n_estimators': 200, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 219, 'gb_learning_rate': 0.013765596778043869, 'gb_max_depth': 7, 'xgb_n_estimators': 318, 'xgb_learning_rate': 0.016339198501593787, 'xgb_max_depth': 4, 'cat_iterations': 187, 'cat_learning_rate': 0.2857674904460431, 'cat_depth': 10, 'lr_C': 0.18438076374470144}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:20:06,810] Trial 75 finished with value: -0.8706379407623484 and parameters: {'rf_n_estimators': 167, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 226, 'gb_learning_rate': 0.015284054628096387, 'gb_max_depth': 6, 'xgb_n_estimators': 327, 'xgb_learning_rate': 0.014941175174704785, 'xgb_max_depth': 4, 'cat_iterations': 233, 'cat_learning_rate': 0.022257943995320297, 'cat_depth': 10, 'lr_C': 0.20435805128796636}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:20:41,456] Trial 76 finished with value: -0.870487819770338 and parameters: {'rf_n_estimators': 169, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 212, 'gb_learning_rate': 0.014365231612640375, 'gb_max_depth': 6, 'xgb_n_estimators': 318, 'xgb_learning_rate': 0.01669723508642249, 'xgb_max_depth': 4, 'cat_iterations': 234, 'cat_learning_rate': 0.021540055285614427, 'cat_depth': 10, 'lr_C': 0.04582913221973962}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:21:15,601] Trial 79 finished with value: -0.8704152842451464 and parameters: {'rf_n_estimators': 169, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 215, 'gb_learning_rate': 0.015343566309070652, 'gb_max_depth': 6, 'xgb_n_estimators': 272, 'xgb_learning_rate': 0.015655792232033474, 'xgb_max_depth': 4, 'cat_iterations': 236, 'cat_learning_rate': 0.02170912099485827, 'cat_depth': 10, 'lr_C': 0.1753558344413082}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:21:15,766] Trial 78 finished with value: -0.8705543871826973 and parameters: {'rf_n_estimators': 170, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 229, 'gb_learning_rate': 0.014287891857478464, 'gb_max_depth': 6, 'xgb_n_estimators': 324, 'xgb_learning_rate': 0.015597136853730896, 'xgb_max_depth': 4, 'cat_iterations': 233, 'cat_learning_rate': 0.02090776367028897, 'cat_depth': 10, 'lr_C': 0.2109765056226322}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:21:23,699] Trial 77 finished with value: -0.8703108422705824 and parameters: {'rf_n_estimators': 170, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 216, 'gb_learning_rate': 0.014693494314906623, 'gb_max_depth': 6, 'xgb_n_estimators': 329, 'xgb_learning_rate': 0.015578304049092623, 'xgb_max_depth': 4, 'cat_iterations': 231, 'cat_learning_rate': 0.018360104952404487, 'cat_depth': 10, 'lr_C': 0.05079893504480609}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:21:46,828] Trial 82 finished with value: -0.8702630973679245 and parameters: {'rf_n_estimators': 170, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 215, 'gb_learning_rate': 0.014748276466376846, 'gb_max_depth': 7, 'xgb_n_estimators': 326, 'xgb_learning_rate': 0.01557715949166286, 'xgb_max_depth': 4, 'cat_iterations': 233, 'cat_learning_rate': 0.01957885734290965, 'cat_depth': 10, 'lr_C': 0.1827161739586344}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:22:00,172] Trial 80 finished with value: -0.8711004695068457 and parameters: {'rf_n_estimators': 167, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 218, 'gb_learning_rate': 0.015588366985977415, 'gb_max_depth': 7, 'xgb_n_estimators': 326, 'xgb_learning_rate': 0.014579169836451807, 'xgb_max_depth': 9, 'cat_iterations': 238, 'cat_learning_rate': 0.02186911981572222, 'cat_depth': 10, 'lr_C': 0.04549206698051917}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:22:03,657] Trial 81 finished with value: -0.8707921935247812 and parameters: {'rf_n_estimators': 207, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 219, 'gb_learning_rate': 0.01544777561974877, 'gb_max_depth': 7, 'xgb_n_estimators': 299, 'xgb_learning_rate': 0.01543071658218596, 'xgb_max_depth': 4, 'cat_iterations': 237, 'cat_learning_rate': 0.02370868252326305, 'cat_depth': 10, 'lr_C': 0.19167456305207184}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:22:05,402] Trial 83 finished with value: -0.8707531712485705 and parameters: {'rf_n_estimators': 169, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 218, 'gb_learning_rate': 0.018228980359354337, 'gb_max_depth': 7, 'xgb_n_estimators': 302, 'xgb_learning_rate': 0.015347343673041726, 'xgb_max_depth': 4, 'cat_iterations': 234, 'cat_learning_rate': 0.021670802921687257, 'cat_depth': 10, 'lr_C': 0.14542130291848873}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:22:06,384] Trial 84 finished with value: -0.8706232500230691 and parameters: {'rf_n_estimators': 169, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 207, 'gb_learning_rate': 0.017726177204860034, 'gb_max_depth': 7, 'xgb_n_estimators': 326, 'xgb_learning_rate': 0.015214226385090542, 'xgb_max_depth': 4, 'cat_iterations': 229, 'cat_learning_rate': 0.020921562847809924, 'cat_depth': 10, 'lr_C': 0.14789010384104445}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:22:19,661] Trial 86 finished with value: -0.8705566826107096 and parameters: {'rf_n_estimators': 169, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 129, 'gb_learning_rate': 0.031035100337083378, 'gb_max_depth': 7, 'xgb_n_estimators': 326, 'xgb_learning_rate': 0.015176200463201981, 'xgb_max_depth': 4, 'cat_iterations': 230, 'cat_learning_rate': 0.023343597708637295, 'cat_depth': 10, 'lr_C': 2.5591727818243335}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:22:46,047] Trial 85 finished with value: -0.8704338772120466 and parameters: {'rf_n_estimators': 170, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 213, 'gb_learning_rate': 0.02958198196976733, 'gb_max_depth': 7, 'xgb_n_estimators': 298, 'xgb_learning_rate': 0.015495649761938356, 'xgb_max_depth': 4, 'cat_iterations': 266, 'cat_learning_rate': 0.022689537561962937, 'cat_depth': 10, 'lr_C': 0.04831182022797998}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:24:05,705] Trial 87 finished with value: -0.8702995946733217 and parameters: {'rf_n_estimators': 171, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 124, 'gb_learning_rate': 0.017811708610269917, 'gb_max_depth': 7, 'xgb_n_estimators': 326, 'xgb_learning_rate': 0.0153863456279903, 'xgb_max_depth': 4, 'cat_iterations': 236, 'cat_learning_rate': 0.023103720105566942, 'cat_depth': 10, 'lr_C': 2.137911392576226}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:24:52,245] Trial 88 finished with value: -0.8712232749055088 and parameters: {'rf_n_estimators': 169, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'gb_n_estimators': 211, 'gb_learning_rate': 0.018046836027379394, 'gb_max_depth': 7, 'xgb_n_estimators': 300, 'xgb_learning_rate': 0.016893940076602533, 'xgb_max_depth': 8, 'cat_iterations': 236, 'cat_learning_rate': 0.04872190072263408, 'cat_depth': 11, 'lr_C': 0.045198554446471355}. Best is trial 33 with value: -0.872420570156773.
# [I 2024-09-22 14:26:31,270] Trial 89 finished with value: -0.8702456521150304 and parameters: {'rf_n_estimators': 170, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'gb_n_estimators': 222, 'gb_learning_rate': 0.01769508683934362, 'gb_max_depth': 7, 'xgb_n_estimators': 325, 'xgb_learning_rate': 0.013191279674227903, 'xgb_max_depth': 8, 'cat_iterations': 236, 'cat_learning_rate': 0.05108725639570455, 'cat_depth': 11, 'lr_C': 2.4447391229854643}. Best is trial 33 with value: -0.872420570156773.

# %%
# Вывод наилучших гиперпараметров
print("Наилучшие гиперпараметры:")
for key, value in study.best_params.items():
    print(f"{key}: {value}")
# Out:
# Наилучшие гиперпараметры:
# rf_n_estimators: 258
# rf_max_depth: 19
# rf_min_samples_split: 4
# gb_n_estimators: 197
# gb_learning_rate: 0.04138497600216118
# gb_max_depth: 3
# xgb_n_estimators: 179
# xgb_learning_rate: 0.07464105371778802
# xgb_max_depth: 4
# cat_iterations: 220
# cat_learning_rate: 0.03332449131296827
# cat_depth: 8
# lr_C: 0.8502376470004751

# %%
import optuna.visualization as vis

vis.plot_optimization_history(study)
vis.plot_param_importances(study)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 import optuna.visualization as vis
# ----> 3 vis.plot_optimization_history(study)
#       4 vis.plot_param_importances(study)
#
# NameError: name 'study' is not defined

# %%
# Обновляем модели с лучшими гиперпараметрами
#best_params = study.best_params

base_learners = [
    ('rf', RandomForestClassifier(
        n_estimators=177,
        max_depth=5,
        min_samples_split=10,
        random_state=42)),
    
    ('gb', GradientBoostingClassifier(
        n_estimators=249,
        learning_rate=0.014558979708316613,
        max_depth=9,
        random_state=42)),
    
    ('xgb', XGBClassifier(
        n_estimators=349,
        learning_rate=0.010495089275623674,
        max_depth=3,
        use_label_encoder=False,
        eval_metric='logloss',
        random_state=42)),
    
    ('cat', CatBoostClassifier(
        iterations=347,
        learning_rate=0.03505955989906093,
        depth=12,
        verbose=0,
        random_state=42))
]

meta_learner = LogisticRegression(
    C=3.9214510817910027,
    max_iter=1000,
    random_state=42)

stacking_clf = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=5,
    n_jobs=-1
)

# %%
# Кросс-валидация на всей обучающей выборке с найденными гиперпараметрами
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(stacking_clf, X_selected, y, cv=cv, scoring='roc_auc', n_jobs=-1)
print(f'\nROC AUC Scores from Cross-Validation: {scores}')
print(f'Mean ROC AUC Score from Cross-Validation: {scores.mean()}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Кросс-валидация на всей обучающей выборке с найденными гиперпараметрами
#       2 cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# ----> 3 scores = cross_val_score(stacking_clf, X_selected, y, cv=cv, scoring='roc_auc', n_jobs=-1)
#       4 print(f'\nROC AUC Scores from Cross-Validation: {scores}')
#       5 print(f'Mean ROC AUC Score from Cross-Validation: {scores.mean()}')
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\miniconda3\Lib\site-packages\sklearn\model_selection\_validation.py:712, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     709 # To ensure multimetric format is not supported
#     710 scorer = check_scoring(estimator, scoring=scoring)
# --> 712 cv_results = cross_validate(
#     713     estimator=estimator,
#     714     X=X,
#     715     y=y,
#     716     groups=groups,
#     717     scoring={"score": scorer},
#     718     cv=cv,
#     719     n_jobs=n_jobs,
#     720     verbose=verbose,
#     721     fit_params=fit_params,
#     722     params=params,
#     723     pre_dispatch=pre_dispatch,
#     724     error_score=error_score,
#     725 )
#     726 return cv_results["test_score"]
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\miniconda3\Lib\site-packages\sklearn\model_selection\_validation.py:423, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     420 # We clone the estimator to make sure that all the folds are
#     421 # independent, and that it is pickle-able.
#     422 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 423 results = parallel(
#     424     delayed(_fit_and_score)(
#     425         clone(estimator),
#     426         X,
#     427         y,
#     428         scorer=scorers,
#     429         train=train,
#     430         test=test,
#     431         verbose=verbose,
#     432         parameters=None,
#     433         fit_params=routed_params.estimator.fit,
#     434         score_params=routed_params.scorer.score,
#     435         return_train_score=return_train_score,
#     436         return_times=True,
#     437         return_estimator=return_estimator,
#     438         error_score=error_score,
#     439     )
#     440     for train, test in indices
#     441 )
#     443 _warn_or_raise_about_fit_failures(results, error_score)
#     445 # For callable scoring, the return type is only know after calling. If the
#     446 # return type is a dictionary, the error scores can now be inserted with
#     447 # the correct key.
#
# File ~\miniconda3\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\miniconda3\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~\miniconda3\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~\miniconda3\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# Обучение модели на всей обучающей выборке
stacking_clf.fit(X_selected, y)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('rf',
#                                 RandomForestClassifier(max_depth=5,
#                                                        min_samples_split=10,
#                                                        n_estimators=177,
#                                                        random_state=42)),
#                                ('gb',
#                                 GradientBoostingClassifier(learning_rate=0.014558979708316613,
#                                                            max_depth=9,
#                                                            n_estimators=249,
#                                                            random_state=42)),
#                                ('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_byno...
#                                               max_delta_step=None, max_depth=3,
#                                               max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=349, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=42, ...)),
#                                ('cat',
#                                 <catboost.core.CatBoostClassifier object at 0x000002DB02782B70>)],
#                    final_estimator=LogisticRegression(C=3.9214510817910027,
#                                                       max_iter=1000,
#                                                       random_state=42),
#                    n_jobs=-1)

# %%
# Предсказания на тестовых данных
test_predictions = stacking_clf.predict_proba(X_test_selected)[:, 1]

# %%
# Создание файла с предсказаниями
submission = pd.DataFrame({
    'Cancellation Probability': test_predictions
})

submission['Cancellation Probability'] = submission['Cancellation Probability'].round(7)

# Сохранение файла
submission.to_csv('submission_final.csv', index=False, header=False)
