# %% [markdown]
# # Предварительный feature selection для фичей

# %%
# !pip install -q git+https://github.com/sb-ai-lab/LightAutoML.git

# %%
import os
if 'drive' not in os.listdir():
    from google.colab import drive
    drive.mount('/content/drive')

path_to_folder = '/content/drive/MyDrive/psb_hack'

# %%
# standard libraries
import sys
import os
import joblib
import gc
import yaml
import warnings
warnings.filterwarnings('ignore')
# ds libraries
import pandas as pd
import numpy as np
from catboost import Pool,CatBoostClassifier,CatBoostRegressor,EFeaturesSelectionAlgorithm,EShapCalcType
from sklearn.model_selection import StratifiedKFold
# lama
from lightautoml.automl.presets.tabular_presets import TabularAutoML
from lightautoml.tasks import Task
# свои функции по оценке метрик
path_to_model_utils = '/content/drive/MyDrive/psb_hack'
sys.path.append(os.path.join(path_to_model_utils,'model_utils'))
from model_estimation import *
from feature_selection import BoostARoota, prepare_datasets_for_feature_selection

# %%
features_pack = 'features_pack_v4'
# опрелелить необходимые параметры для обработки признаков
config_model = dict(
                    # group_filter = None,#{'column' : 'product', 'value' : product_dict[product]},
                    n_threads = 1,
                    n_folds = 5,
                    random_state = 42,
                    task = dict(name='binary',metric='auc', loss='logloss',greater_is_better=True),
                    advanced_roles = False,
                    roles = {'target': 'target',
                             'category': ['Способ оплаты', 'Источник', 'Категория номера'],
                             'drop' : ['Дата бронирования','Дата отмены', 'Заезд', 'Выезд',
                                       'Категория номера', 'mon','Статус брони','№ брони']}
                    )

# for cb selection
iterations = 300
steps = 5

# %% [markdown]
# ## Загрузка и предобработка данных

# %%
# чтение данных
dates = ['Дата бронирования','Дата отмены', 'Заезд', 'Выезд']
train_full = pd.read_csv(os.path.join(path_to_folder,'data',f'full_train_{features_pack}.csv'),parse_dates=dates)
train = pd.read_csv(os.path.join(path_to_folder,'data',f'train_{features_pack}.csv'),parse_dates=dates)
oot_val = pd.read_csv(os.path.join(path_to_folder,'data',f'oot_val_{features_pack}.csv'),parse_dates=dates)
oof_val = pd.read_csv(os.path.join(path_to_folder,'data',f'oof_val_{features_pack}.csv'),parse_dates=dates)

gc.collect()
X_train, y_train, X_val_oot, y_val_oot = prepare_datasets_for_feature_selection(train, oot_val, config_model)
# Out:
# [12:46:04] Train data shape: (15987, 109)
# INFO:lightautoml.reader.base:Train data shape: (15987, 109)

# %%
print(X_train.info())
print('количество категориальных признаков:',X_train.select_dtypes(include='object').columns.shape)
assert set(X_train.columns.tolist()) == set(X_val_oot.columns.tolist()), 'Не совпадают признаки между train val'
category_cols = X_train.select_dtypes(include='object').columns.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15987 entries, 0 to 15986
# Data columns (total 87 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   booking_season              15987 non-null  object
#  1   checkin_season              15987 non-null  object
#  2   checkout_season             15987 non-null  object
#  3   Источник                    15987 non-null  object
#  4   Способ оплаты               15987 non-null  object
#  5   avg_cost_per_person         15987 non-null  float32
#  6   booking_day                 15987 non-null  float32
#  7   booking_dayofweek           15987 non-null  float32
#  8   booking_dayofweek_cos       15987 non-null  float32
#  9   booking_dayofweek_sin       15987 non-null  float32
#  10  booking_is_month_end        15987 non-null  float32
#  11  booking_is_month_start      15987 non-null  float32
#  12  booking_is_quarter_end      15987 non-null  float32
#  13  booking_is_quarter_start    15987 non-null  float32
#  14  booking_is_weekend          15987 non-null  float32
#  15  booking_is_year_end         15987 non-null  float32
#  16  booking_is_year_start       15987 non-null  float32
#  17  booking_month               15987 non-null  float32
#  18  booking_month_cos           15987 non-null  float32
#  19  booking_month_sin           15987 non-null  float32
#  20  booking_quarter             15987 non-null  float32
#  21  booking_to_checkin_days     15987 non-null  float32
#  22  booking_to_checkin_months   15987 non-null  float32
#  23  booking_to_checkout_days    15987 non-null  float32
#  24  booking_weekofyear          15987 non-null  float32
#  25  booking_year                15987 non-null  float32
#  26  checkin_day                 15987 non-null  float32
#  27  checkin_dayofweek           15987 non-null  float32
#  28  checkin_dayofweek_cos       15987 non-null  float32
#  29  checkin_dayofweek_sin       15987 non-null  float32
#  30  checkin_is_month_end        15987 non-null  float32
#  31  checkin_is_month_start      15987 non-null  float32
#  32  checkin_is_quarter_end      15987 non-null  float32
#  33  checkin_is_quarter_start    15987 non-null  float32
#  34  checkin_is_weekend          15987 non-null  float32
#  35  checkin_is_year_end         15987 non-null  float32
#  36  checkin_month               15987 non-null  float32
#  37  checkin_month_cos           15987 non-null  float32
#  38  checkin_month_sin           15987 non-null  float32
#  39  checkin_quarter             15987 non-null  float32
#  40  checkin_to_checkout_days    15987 non-null  float32
#  41  checkin_weekofyear          15987 non-null  float32
#  42  checkin_year                15987 non-null  float32
#  43  checkout_day                15987 non-null  float32
#  44  checkout_dayofweek          15987 non-null  float32
#  45  checkout_dayofweek_cos      15987 non-null  float32
#  46  checkout_dayofweek_sin      15987 non-null  float32
#  47  checkout_is_month_end       15987 non-null  float32
#  48  checkout_is_month_start     15987 non-null  float32
#  49  checkout_is_quarter_end     15987 non-null  float32
#  50  checkout_is_quarter_start   15987 non-null  float32
#  51  checkout_is_weekend         15987 non-null  float32
#  52  checkout_month              15987 non-null  float32
#  53  checkout_month_cos          15987 non-null  float32
#  54  checkout_month_sin          15987 non-null  float32
#  55  checkout_quarter            15987 non-null  float32
#  56  checkout_weekofyear         15987 non-null  float32
#  57  checkout_year               15987 non-null  float32
#  58  cost_per_guest              15987 non-null  float32
#  59  cost_per_night              15987 non-null  float32
#  60  cost_per_night_per_guest    15987 non-null  float32
#  61  cost_per_night_per_room     15987 non-null  float32
#  62  cost_per_room               15987 non-null  float32
#  63  guests_per_room             15987 non-null  float32
#  64  has_prepayment              15987 non-null  float32
#  65  is_early_booking            15987 non-null  float32
#  66  is_last_week_booking        15987 non-null  float32
#  67  nights_per_guest            15987 non-null  float32
#  68  prepayment_ratio            15987 non-null  float32
#  69  region                      15987 non-null  float32
#  70  remaining_payment           15987 non-null  float32
#  71  remaining_payment_ratio     15987 non-null  float32
#  72  room_category_digits        15987 non-null  float32
#  73  room_category_length        15987 non-null  float32
#  74  room_category_num           15987 non-null  float32
#  75  room_category_title_case    15987 non-null  float32
#  76  room_category_unique_chars  15987 non-null  float32
#  77  room_category_uppercase     15987 non-null  float32
#  78  room_category_words         15987 non-null  float32
#  79  rooms_per_guest             15987 non-null  float32
#  80  rooms_times_nights          15987 non-null  float32
#  81  Внесена предоплата          15987 non-null  float32
#  82  Гостей                      15987 non-null  float32
#  83  Гостиница                   15987 non-null  float32
#  84  Номеров                     15987 non-null  float32
#  85  Ночей                       15987 non-null  float32
#  86  Стоимость                   15987 non-null  float32
# dtypes: float32(82), object(5)
# memory usage: 5.6+ MB
# None
# количество категориальных признаков: (5,)

# %% [markdown]
# ## Feature selection with catboost

# %%
# подготовим pool для турбокошки
X_train_cb = X_train.astype(dict(zip(category_cols,[str] * len(category_cols)))).fillna(dict(zip(category_cols,['None'] * len(category_cols))))
X_val_oot_cb = X_val_oot.astype(dict(zip(category_cols,[str] * len(category_cols)))).fillna(dict(zip(category_cols,['None'] * len(category_cols))))

train_pool = Pool(X_train_cb, label=y_train, cat_features=category_cols)
val_pool = Pool(X_val_oot_cb, label=y_val_oot,cat_features=category_cols)


# здесь могут быть проблемы с objective МОЖЕТ ПРИДЕТСЯ ИСПРАВЛЯТЬ ОШИБКУ
if config_model['task']['name'] == 'reg':
    boosting = CatBoostRegressor(objective='MAE',
                                iterations=iterations,
                                random_seed=42,
                                use_best_model=True)
elif config_model['task']['name'] == 'binary':
    boosting = CatBoostClassifier(objective='Logloss',
                                iterations=iterations,
                                random_seed=42,
                                use_best_model=True)
elif config_model['task']['name'] == 'multiclass':
    boosting = CatBoostClassifier(objective='MultiClass',
                                iterations=iterations,
                                random_seed=42,
                                use_best_model=True)
selector_boosting = boosting.copy()
# первый этап
print('Изначальное кол-во признаков',len(train_pool.get_feature_names()))
feature_selection = boosting.select_features(
    train_pool,
    eval_set=val_pool,
    features_for_select=train_pool.get_feature_names(),
    num_features_to_select=10,
    verbose=False,
    steps=steps,
    algorithm=EFeaturesSelectionAlgorithm.RecursiveByLossFunctionChange,
    shap_calc_type=EShapCalcType.Regular,
    train_final_model=False,
)
# второй этап
optimal_removed_features = feature_selection['loss_graph']['removed_features_count'][np.argmin(feature_selection['loss_graph']['loss_values'])]
final_num_features = len(train_pool.get_feature_names()) - optimal_removed_features
print(f'Будем отбирать {final_num_features} фичей')
feature_selection = selector_boosting.select_features(
    train_pool,
    eval_set=val_pool,
    features_for_select=train_pool.get_feature_names(),
    num_features_to_select=final_num_features,
    verbose=100,
    steps=steps,
    algorithm=EFeaturesSelectionAlgorithm.RecursiveByLossFunctionChange,
    shap_calc_type=EShapCalcType.Regular,
    train_final_model=False
)
cb_selected_features = feature_selection['selected_features_names']
print('Кол-во отобранных признаков:', len(cb_selected_features))
print('Кол-во категориальных фичей:',len(set(cb_selected_features) & set(category_cols)))
# Out:
# Изначальное кол-во признаков 87
# Learning rate set to 0.106094
# Step #1 out of 5
#
# bestTest = 0.2863951142
# bestIteration = 138
#
# Shrink model to first 139 iterations.
# Feature #65 eliminated
# Feature #24 eliminated
# Feature #18 eliminated
# Feature #23 eliminated
# Feature #58 eliminated
# Feature #56 eliminated
# Feature #42 eliminated
# Feature #70 eliminated
# Feature #79 eliminated
# Feature #26 eliminated
# Feature #29 eliminated
# Feature #22 eliminated
# Feature #73 eliminated
# Feature #37 eliminated
# Feature #52 eliminated
# Feature #67 eliminated
# Feature #39 eliminated
# Feature #41 eliminated
# Feature #9 eliminated
# Feature #75 eliminated
# Feature #86 eliminated
# Feature #59 eliminated
# Feature #69 eliminated
# Feature #83 eliminated
# Feature #66 eliminated
# Feature #57 eliminated
# Feature #0 eliminated
# Feature #48 eliminated
# Feature #17 eliminated
# Feature #54 eliminated
# Feature #40 eliminated
# Step #2 out of 5
#
# bestTest = 0.2840441835
# bestIteration = 79
#
# Shrink model to first 80 iterations.
# Feature #46 eliminated
# Feature #38 eliminated
# Feature #6 eliminated
# Feature #25 eliminated
# Feature #85 eliminated
# Feature #7 eliminated
# Feature #1 eliminated
# Feature #62 eliminated
# Feature #53 eliminated
# Feature #45 eliminated
# Feature #36 eliminated
# Feature #34 eliminated
# Feature #27 eliminated
# Feature #78 eliminated
# Feature #15 eliminated
# Feature #14 eliminated
# Feature #35 eliminated
# Feature #80 eliminated
# Feature #16 eliminated
# Step #3 out of 5
#
# bestTest = 0.2849640635
# bestIteration = 59
#
# Shrink model to first 60 iterations.
# Feature #20 eliminated
# Feature #60 eliminated
# Feature #8 eliminated
# Feature #28 eliminated
# Feature #51 eliminated
# Feature #44 eliminated
# Feature #19 eliminated
# Feature #76 eliminated
# Feature #30 eliminated
# Feature #11 eliminated
# Feature #10 eliminated
# Feature #12 eliminated
# Feature #13 eliminated
# Step #4 out of 5
#
# bestTest = 0.2839052558
# bestIteration = 69
#
# Shrink model to first 70 iterations.
# Feature #5 eliminated
# Feature #43 eliminated
# Feature #2 eliminated
# Feature #84 eliminated
# Feature #63 eliminated
# Feature #49 eliminated
# Feature #33 eliminated
# Feature #32 eliminated
# Feature #47 eliminated
# Step #5 out of 5
#
# bestTest = 0.2857969766
# bestIteration = 53
#
# Shrink model to first 54 iterations.
# Feature #61 eliminated
# Feature #55 eliminated
# Feature #50 eliminated
# Feature #82 eliminated
# Feature #77 eliminated
# Будем отбирать 27 фичей
# Learning rate set to 0.106094
# Step #1 out of 5
# 0:	learn: 0.6063474	test: 0.6077593	best: 0.6077593 (0)	total: 75.5ms	remaining: 22.6s
# 100:	learn: 0.2605654	test: 0.2874330	best: 0.2874330 (100)	total: 5.06s	remaining: 9.96s
# 200:	learn: 0.2344142	test: 0.2888933	best: 0.2863951 (138)	total: 9.09s	remaining: 4.48s
# 299:	learn: 0.2138044	test: 0.2925224	best: 0.2863951 (138)	total: 14.1s	remaining: 0us
#
# bestTest = 0.2863951142
# bestIteration = 138
#
# Shrink model to first 139 iterations.
# Feature #65 eliminated
# Feature #24 eliminated
# Feature #18 eliminated
# Feature #23 eliminated
# Feature #58 eliminated
# Feature #56 eliminated
# Feature #42 eliminated
# Feature #70 eliminated
# Feature #79 eliminated
# Feature #26 eliminated
# Feature #29 eliminated
# Feature #22 eliminated
# Feature #73 eliminated
# Feature #37 eliminated
# Feature #52 eliminated
# Feature #67 eliminated
# Feature #39 eliminated
# Feature #41 eliminated
# Step #2 out of 5
# 0:	learn: 0.5858844	test: 0.5917363	best: 0.5917363 (0)	total: 82.5ms	remaining: 24.7s
# 100:	learn: 0.2636622	test: 0.2860314	best: 0.2860314 (100)	total: 5.07s	remaining: 9.98s
# 200:	learn: 0.2385226	test: 0.2900569	best: 0.2858561 (101)	total: 8.89s	remaining: 4.38s
# 299:	learn: 0.2170645	test: 0.2928942	best: 0.2858561 (101)	total: 12.8s	remaining: 0us
#
# bestTest = 0.2858561296
# bestIteration = 101
#
# Shrink model to first 102 iterations.
# Feature #59 eliminated
# Feature #38 eliminated
# Feature #28 eliminated
# Feature #7 eliminated
# Feature #1 eliminated
# Feature #9 eliminated
# Feature #55 eliminated
# Feature #61 eliminated
# Feature #62 eliminated
# Feature #85 eliminated
# Feature #60 eliminated
# Feature #36 eliminated
# Feature #8 eliminated
# Feature #75 eliminated
# Feature #86 eliminated
# Step #3 out of 5
# 0:	learn: 0.6061315	test: 0.6064586	best: 0.6064586 (0)	total: 68.2ms	remaining: 20.4s
# 100:	learn: 0.2648687	test: 0.2837643	best: 0.2820777 (84)	total: 5.25s	remaining: 10.3s
# 200:	learn: 0.2424402	test: 0.2903441	best: 0.2820777 (84)	total: 8.52s	remaining: 4.2s
# 299:	learn: 0.2236258	test: 0.2929023	best: 0.2820777 (84)	total: 11.8s	remaining: 0us
#
# bestTest = 0.2820776917
# bestIteration = 84
#
# Shrink model to first 85 iterations.
# Feature #20 eliminated
# Feature #2 eliminated
# Feature #27 eliminated
# Feature #17 eliminated
# Feature #80 eliminated
# Feature #78 eliminated
# Feature #30 eliminated
# Feature #69 eliminated
# Feature #76 eliminated
# Feature #0 eliminated
# Feature #84 eliminated
# Step #4 out of 5
# 0:	learn: 0.5872920	test: 0.5941446	best: 0.5941446 (0)	total: 30.5ms	remaining: 9.13s
# 100:	learn: 0.2632832	test: 0.2888668	best: 0.2873194 (58)	total: 3.16s	remaining: 6.23s
# 200:	learn: 0.2405377	test: 0.2932511	best: 0.2873194 (58)	total: 7.75s	remaining: 3.82s
# 299:	learn: 0.2204971	test: 0.2964335	best: 0.2873194 (58)	total: 10.3s	remaining: 0us
#
# bestTest = 0.2873194368
# bestIteration = 58
#
# Shrink model to first 59 iterations.
# Feature #53 eliminated
# Feature #57 eliminated
# Feature #19 eliminated
# Feature #51 eliminated
# Feature #83 eliminated
# Feature #34 eliminated
# Feature #43 eliminated
# Feature #40 eliminated
# Feature #46 eliminated
# Step #5 out of 5
# 0:	learn: 0.6072733	test: 0.6070936	best: 0.6070936 (0)	total: 26.9ms	remaining: 8.03s
# 100:	learn: 0.2666199	test: 0.2826897	best: 0.2824991 (96)	total: 2.46s	remaining: 4.84s
# 200:	learn: 0.2451857	test: 0.2847817	best: 0.2824961 (101)	total: 4.97s	remaining: 2.45s
# 299:	learn: 0.2278963	test: 0.2880179	best: 0.2824961 (101)	total: 8.31s	remaining: 0us
#
# bestTest = 0.2824960982
# bestIteration = 101
#
# Shrink model to first 102 iterations.
# Feature #6 eliminated
# Feature #10 eliminated
# Feature #5 eliminated
# Feature #82 eliminated
# Feature #45 eliminated
# Feature #48 eliminated
# Feature #50 eliminated
# Кол-во отобранных признаков: 27
# Кол-во категориальных фичей: 2

# %% [markdown]
# ## Feature selection with boostaroota

# %%
# X_train_br = X_train.astype(dict(zip(category_cols,['category'] * len(category_cols))))

# br = BoostARoota(
#     metric=config_model['task']['metric'] if config_model['task']['metric'] != 'medianae' else 'mae',
#     iters=10,
#     cutoff=1,
#     device = None,
#     random_state=42,
# )
# br.fit(X_train_br, y_train)
# boosta_selected_features = br.keep_vars_.values.tolist()

# print('Кол-во отобранных признаков:', len(boosta_selected_features))
# print('Кол-во категориальных фичей:',len(set(boosta_selected_features) & set(category_cols)))

# %% [markdown]
# ## Feature selection with automl

# %%
task = Task(name=config_model['task']['name'],
                metric=config_model['task']['metric'],
                loss=config_model['task']['loss'],
                greater_is_better=config_model['task']['greater_is_better'])
reader_params = {'n_jobs' : config_model['n_threads'],
                 'cv': config_model['n_folds'],
                 'random_state' : config_model['random_state'],
                 'advanced_roles' : config_model['advanced_roles']
                 }

model = TabularAutoML(
        task = task,
        timeout= 60*60*10,
        cpu_limit=-1,
        general_params={'use_algos': [['cb',]], 'weighted_blender_max_nonzero_coef' : 0.05,},
        reader_params=reader_params,
        tuning_params=config_model.get('tuning_params', {'max_tuning_iter': 5}),
        selection_params={'mode':1, 'importance_type': 'permutation','fit_on_holdout': False, 'cutoff': 0, 'select_algos': [ 'gbm']}
)
cv = StratifiedKFold(n_splits=config_model['n_folds'],shuffle=True, random_state=config_model['random_state'])
train_pred = model.fit_predict(train_full,
                               roles=config_model['roles'],
                               verbose=1,
                               cv_iter=list(cv.split(train_full,train_full[config_model['roles']['target']])))

automl_selected_features = model.reader.used_features
# Out:
# [12:48:01] Stdout logging level is INFO.
# INFO:lightautoml.automl.presets.base:Stdout logging level is INFO.
# [12:48:01] Task: binary
# INFO:lightautoml.automl.presets.base:Task: binary
# [12:48:01] Start automl preset with listed constraints:
# INFO:lightautoml.automl.presets.base:Start automl preset with listed constraints:
# [12:48:01] - time: 36000.00 seconds
# INFO:lightautoml.automl.presets.base:- time: 36000.00 seconds
# [12:48:01] - CPU: 2 cores
# INFO:lightautoml.automl.presets.base:- CPU: 2 cores
# [12:48:01] - memory: 16 GB
# INFO:lightautoml.automl.presets.base:- memory: 16 GB
# [12:48:02] Train data shape: (26174, 109)
# INFO:lightautoml.reader.base:Train data shape: (26174, 109)
# [12:48:02] Layer 1 train process start. Time left 35999.75 secs
# INFO:lightautoml.automl.base:Layer 1 train process start. Time left 35999.75 secs
# [12:48:02] Start fitting Selector_LightGBM ...
# INFO:lightautoml.ml_algo.base:Start fitting Selector_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.03, 'num_leaves': 32, 'feature_fraction': 1, 'bagging_fraction': 0.7, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 1200, 'early_stopping_rounds': 200, 'random_state': 42}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Selector_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.862301
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.860345
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [92]	valid's auc: 0.862713
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Selector_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.860999
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.860916
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's auc: 0.859213
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [139]	valid's auc: 0.862286
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Selector_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.849914
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.851668
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's auc: 0.85009
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's auc: 0.848167
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [234]	valid's auc: 0.852493
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Selector_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.86658
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.866481
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's auc: 0.86575
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [109]	valid's auc: 0.867484
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Selector_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's auc: 0.861974
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's auc: 0.86
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's auc: 0.859295
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [108]	valid's auc: 0.862464
# [12:48:20] Fitting Selector_LightGBM finished. score = 0.8608324295209966
# INFO:lightautoml.ml_algo.base:Fitting Selector_LightGBM finished. score = 0.8608324295209966
# [12:48:20] Selector_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Selector_LightGBM fitting and predicting completed
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal score = 0.8608324295209966
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (0,ord__booking_season)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col ord__booking_season = 0.9044624600453628, difference with normal = -0.0436300305243662
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (1,ord__checkin_season)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col ord__checkin_season = 0.9047727359014456, difference with normal = -0.04394030638044899
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (2,ord__checkout_season)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col ord__checkout_season = 0.9049881555237236, difference with normal = -0.04415572600272699
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (3,ord__Источник)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col ord__Источник = 0.8832295941095009, difference with normal = -0.02239716458850427
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (4,ord__Способ оплаты)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col ord__Способ оплаты = 0.8897839271653933, difference with normal = -0.02895149764439675
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (5,avg_cost_per_person)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col avg_cost_per_person = 0.9004317562753547, difference with normal = -0.039599326754358066
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (6,booking_day)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_day = 0.9004701219432489, difference with normal = -0.039637692422252346
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (7,booking_dayofweek)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_dayofweek = 0.9039801468248005, difference with normal = -0.043147717303803956
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (8,booking_dayofweek_cos)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_dayofweek_cos = 0.904370623862937, difference with normal = -0.043538194341940395
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (9,booking_dayofweek_sin)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_dayofweek_sin = 0.9043041781428619, difference with normal = -0.043471748621865314
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (10,booking_is_month_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_is_month_end = 0.9050561847053876, difference with normal = -0.044223755184391034
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (11,booking_is_month_start)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_is_month_start = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (12,booking_is_quarter_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_is_quarter_end = 0.9052174958387548, difference with normal = -0.04438506631775818
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (13,booking_is_quarter_start)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_is_quarter_start = 0.9052473980191988, difference with normal = -0.044414968498202256
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (14,booking_is_weekend)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_is_weekend = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (15,booking_is_year_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_is_year_end = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (16,booking_is_year_start)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_is_year_start = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (17,booking_month)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_month = 0.9047379318746908, difference with normal = -0.04390550235369417
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (18,booking_month_cos)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_month_cos = 0.9045046306108149, difference with normal = -0.043672201089818286
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (19,booking_month_sin)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_month_sin = 0.9021599462537336, difference with normal = -0.041327516732737046
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (20,booking_quarter)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_quarter = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (21,booking_to_checkin_days)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_to_checkin_days = 0.8727149318243137, difference with normal = -0.01188250230331711
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (22,booking_to_checkin_months)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_to_checkin_months = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (23,booking_to_checkout_days)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_to_checkout_days = 0.8917346692278171, difference with normal = -0.03090223970682049
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (24,booking_weekofyear)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_weekofyear = 0.9027104492969908, difference with normal = -0.04187801977599426
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (25,booking_year)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col booking_year = 0.9043304819642164, difference with normal = -0.0434980524432198
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (26,checkin_day)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_day = 0.9019101127329185, difference with normal = -0.041077683211921956
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (27,checkin_dayofweek)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_dayofweek = 0.9039101165148673, difference with normal = -0.04307768699387071
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (28,checkin_dayofweek_cos)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_dayofweek_cos = 0.9038025604601435, difference with normal = -0.04297013093914692
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (29,checkin_dayofweek_sin)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_dayofweek_sin = 0.904462717071012, difference with normal = -0.04363028755001541
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (30,checkin_is_month_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_is_month_end = 0.9052213558132373, difference with normal = -0.04438892629224067
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (31,checkin_is_month_start)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_is_month_start = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (32,checkin_is_quarter_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_is_quarter_end = 0.9051954742483065, difference with normal = -0.0443630447273099
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (33,checkin_is_quarter_start)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_is_quarter_start = 0.9052599371990873, difference with normal = -0.04442750767809067
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (34,checkin_is_weekend)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_is_weekend = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (35,checkin_is_year_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_is_year_end = 0.9052656606095268, difference with normal = -0.044433231088530256
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (36,checkin_month)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_month = 0.9048281203391153, difference with normal = -0.043995690818118716
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (37,checkin_month_cos)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_month_cos = 0.9047012552324916, difference with normal = -0.043868825711494974
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (38,checkin_month_sin)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_month_sin = 0.9048388557497152, difference with normal = -0.04400642622871864
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (39,checkin_quarter)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_quarter = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (40,checkin_to_checkout_days)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_to_checkout_days = 0.9050859859114695, difference with normal = -0.0442535563904729
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (41,checkin_weekofyear)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_weekofyear = 0.9033405017786911, difference with normal = -0.042508072257694485
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (42,checkin_year)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkin_year = 0.9032257765442505, difference with normal = -0.042393347023253924
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (43,checkout_day)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_day = 0.9020290788905715, difference with normal = -0.0411966493695749
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (44,checkout_dayofweek)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_dayofweek = 0.9040711109559165, difference with normal = -0.043238681434919934
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (45,checkout_dayofweek_cos)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_dayofweek_cos = 0.9048826969818873, difference with normal = -0.04405026746089069
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (46,checkout_dayofweek_sin)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_dayofweek_sin = 0.9045720493565621, difference with normal = -0.04373961983556551
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (47,checkout_is_month_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_is_month_end = 0.905209440838497, difference with normal = -0.04437701131750038
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (48,checkout_is_month_start)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_is_month_start = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (49,checkout_is_quarter_end)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_is_quarter_end = 0.9051937714533802, difference with normal = -0.04436134193238361
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (50,checkout_is_quarter_start)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_is_quarter_start = 0.9051916096840803, difference with normal = -0.04435918016308371
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (51,checkout_is_weekend)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_is_weekend = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (52,checkout_month)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_month = 0.9043069962455161, difference with normal = -0.04347456672451955
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (53,checkout_month_cos)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_month_cos = 0.9044904987898498, difference with normal = -0.043658069268853184
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (54,checkout_month_sin)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_month_sin = 0.9047802171837361, difference with normal = -0.043947787662739546
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (55,checkout_quarter)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_quarter = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (56,checkout_weekofyear)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_weekofyear = 0.9029170244830883, difference with normal = -0.042084594962091715
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (57,checkout_year)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col checkout_year = 0.904567482561544, difference with normal = -0.04373505304054737
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (58,cost_per_guest)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col cost_per_guest = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (59,cost_per_night)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col cost_per_night = 0.9019132842458404, difference with normal = -0.041080854724843796
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (60,cost_per_night_per_guest)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col cost_per_night_per_guest = 0.8997324583299003, difference with normal = -0.03890002880890375
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (61,cost_per_night_per_room)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col cost_per_night_per_room = 0.9020267151725472, difference with normal = -0.04119428565155059
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (62,cost_per_room)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col cost_per_room = 0.9017069890341108, difference with normal = -0.04087455951311425
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (63,guests_per_room)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col guests_per_room = 0.9042763229881244, difference with normal = -0.04344389346712785
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (64,has_prepayment)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col has_prepayment = 0.9052564765323099, difference with normal = -0.044424047011313306
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (65,is_early_booking)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col is_early_booking = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (66,is_last_week_booking)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col is_last_week_booking = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (67,nights_per_guest)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col nights_per_guest = 0.9039322666181402, difference with normal = -0.0430998370971436
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (68,prepayment_ratio)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col prepayment_ratio = 0.8868672322259055, difference with normal = -0.026034802704908877
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (69,region)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col region = 0.9045045847133776, difference with normal = -0.04367215519238099
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (70,remaining_payment)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col remaining_payment = 0.9016088098258409, difference with normal = -0.04077638030484432
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (71,remaining_payment_ratio)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col remaining_payment_ratio = 0.8755151757857162, difference with normal = -0.01468274626471966
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (72,room_category_digits)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col room_category_digits = 0.9052346339418672, difference with normal = -0.04440220442087062
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (73,room_category_length)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col room_category_length = 0.9046594472567946, difference with normal = -0.043827017735798
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (74,room_category_num)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col room_category_num = 0.9049862691390478, difference with normal = -0.044153839618051194
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (75,room_category_title_case)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col room_category_title_case = 0.9049646376768171, difference with normal = -0.04413220815582053
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (76,room_category_unique_chars)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col room_category_unique_chars = 0.9050222756786617, difference with normal = -0.04418984615766508
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (77,room_category_uppercase)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col room_category_uppercase = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (78,room_category_words)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col room_category_words = 0.9051769775810479, difference with normal = -0.04434454806005128
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (79,rooms_per_guest)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col rooms_per_guest = 0.9050857242960765, difference with normal = -0.04425329477507989
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (80,rooms_times_nights)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col rooms_times_nights = 0.904674634718819, difference with normal = -0.04384220519782245
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (81,Внесена предоплата)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col Внесена предоплата = 0.7997625799000949, difference with normal = 0.06106984962090167
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (82,Гостей)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col Гостей = 0.9046614942825011, difference with normal = -0.0438290647615045
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (83,Гостиница)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col Гостиница = 0.903834459179113, difference with normal = -0.04300202965811639
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (84,Номеров)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col Номеров = 0.9050776279881252, difference with normal = -0.0442451984671286
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (85,Ночей)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col Ночей = 0.9052646784043672, difference with normal = -0.044432248883370606
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Start processing (86,Стоимость)
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# INFO3:lightautoml.pipelines.selection.permutation_importance_based:Shuffled column set
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Shuffled score for col Стоимость = 0.9019624220422847, difference with normal = -0.04112999252128813
# DEBUG:lightautoml.pipelines.selection.permutation_importance_based:Normal column set
# [12:49:38] Start fitting Lvl_0_Pipe_0_Mod_0_CatBoost ...
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_0_Mod_0_CatBoost ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task_type': 'CPU', 'thread_count': 2, 'random_seed': 42, 'num_trees': 5000, 'learning_rate': 0.03, 'l2_leaf_reg': 0.01, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 1, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'boost_from_average': True, 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': 100, 'allow_writing_files': False}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.7515643	best: 0.7515643 (0)	total: 4.78ms	remaining: 23.9s
# DEBUG:lightautoml.ml_algo.boost_cb:100:	test: 0.7580052	best: 0.7600072 (47)	total: 420ms	remaining: 20.4s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.7600072391
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 47
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 48 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.7420194	best: 0.7420194 (0)	total: 4.17ms	remaining: 20.9s
# DEBUG:lightautoml.ml_algo.boost_cb:100:	test: 0.7464748	best: 0.7466145 (87)	total: 429ms	remaining: 20.8s
# DEBUG:lightautoml.ml_algo.boost_cb:200:	test: 0.7466677	best: 0.7469001 (193)	total: 824ms	remaining: 19.7s
# DEBUG:lightautoml.ml_algo.boost_cb:300:	test: 0.7475070	best: 0.7475921 (259)	total: 1.24s	remaining: 19.3s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.7475921199
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 259
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 260 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.7440303	best: 0.7440303 (0)	total: 4.24ms	remaining: 21.2s
# DEBUG:lightautoml.ml_algo.boost_cb:100:	test: 0.7615140	best: 0.7625079 (48)	total: 426ms	remaining: 20.6s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.762507902
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 48
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 49 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.7532138	best: 0.7532138 (0)	total: 9.45ms	remaining: 47.3s
# DEBUG:lightautoml.ml_algo.boost_cb:100:	test: 0.7564435	best: 0.7598752 (11)	total: 440ms	remaining: 21.3s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.7598751609
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 11
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 12 iterations.
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_CatBoost =====
# INFO3:lightautoml.ml_algo.boost_cb:0:	test: 0.7670407	best: 0.7670407 (0)	total: 4.81ms	remaining: 24s
# DEBUG:lightautoml.ml_algo.boost_cb:100:	test: 0.7649063	best: 0.7692379 (2)	total: 429ms	remaining: 20.8s
# INFO3:lightautoml.ml_algo.boost_cb:Stopped by overfitting detector  (100 iterations wait)
# INFO3:lightautoml.ml_algo.boost_cb:bestTest = 0.7692378603
# INFO3:lightautoml.ml_algo.boost_cb:bestIteration = 2
# INFO3:lightautoml.ml_algo.boost_cb:Shrink model to first 3 iterations.
# [12:49:42] Fitting Lvl_0_Pipe_0_Mod_0_CatBoost finished. score = 0.748742277113599
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_0_Mod_0_CatBoost finished. score = 0.748742277113599
# [12:49:42] Lvl_0_Pipe_0_Mod_0_CatBoost fitting and predicting completed
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_0_Mod_0_CatBoost fitting and predicting completed
# [12:49:42] Time left 35899.67 secs
# INFO:lightautoml.automl.base:Time left 35899.67 secs
# [12:49:42] Layer 1 training completed.
# INFO:lightautoml.automl.base:Layer 1 training completed.
# [12:49:42] Automl preset training completed in 100.34 seconds
# INFO:lightautoml.automl.presets.base:Automl preset training completed in 100.34 seconds
# [12:49:42] Model description:
# Final prediction for new objects (level 0) =
# 	 1.00000 * (5 averaged models Lvl_0_Pipe_0_Mod_0_CatBoost)
# INFO:lightautoml.automl.presets.base:Model description:
# Final prediction for new objects (level 0) =
# 	 1.00000 * (5 averaged models Lvl_0_Pipe_0_Mod_0_CatBoost)

# %% [markdown]
# ### Сохраним оставленные фичи в новый датасет

# %%
# %%time
# колонки для сохранения
important_cols = config_model['roles']['drop'] + [config_model['roles']['target']]
saved_features_cb = sorted(set(cb_selected_features + important_cols) & set(train_full.columns.tolist()))
print('Осталось фичей для моделирования от catboost:',len(saved_features_cb))
# saved_features_br= sorted(set(boosta_selected_features + important_cols) & set(train_full.columns.tolist()))
# print('Осталось фичей для моделирования от catboost:',len(saved_features_br))
saved_features_aml= sorted(set(automl_selected_features + important_cols) & set(train_full.columns.tolist()))
print('Осталось фичей для моделирования от automl:',len(saved_features_aml))

features_cb_table_file = os.path.join(path_to_folder,'data',features_pack + '_' + 'cb_features.xlsx')
model_features = pd.DataFrame(data = saved_features_cb,columns=['Feature'])
model_features.to_excel(features_cb_table_file)

features_aml_table_file = os.path.join(path_to_folder,'data',features_pack + '_' + 'automl_features.xlsx')
model_features = pd.DataFrame(data = saved_features_aml,columns=['Feature'])
model_features.to_excel(features_aml_table_file)
# Out:
# Осталось фичей для моделирования от catboost: 36
# Осталось фичей для моделирования от automl: 10
# CPU times: user 42.9 ms, sys: 2.93 ms, total: 45.8 ms
# Wall time: 74.9 ms
